# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.192877
# Nearest to its: hernando, kenji, casual, tremont, clinician, approximation, ghibli, vis,
# Nearest to b: deployed, sportswriters, germ, devalued, evaluation, harvester, dianetic, bjarne,
# Nearest to five: bonzo, druidic, psp, dalglish, corcovado, bring, vacation, predators,
# Nearest to the: eddie, uninhabited, justifiable, enciphered, ne, dissipates, oversaw, mouvement,
# Nearest to two: dalek, humphries, metabolize, crashed, gianfranco, rankin, fianc, cei,
# Nearest to were: screwtape, opposites, llama, ales, hobbs, mondegreen, olimp, agriculturally,
# Nearest to be: disciples, yardage, david, haganah, wiki, scorpion, lombardo, wyatt,
# Nearest to while: semiconductor, weren, warplanes, colossians, geographers, electrocution, argus, salah,
# Nearest to they: buenos, verbose, renfrew, furlongs, kantian, lon, hillel, wojty,
# Nearest to see: plumage, dignity, aleppo, doubt, feat, privatized, oahu, alan,
# Nearest to of: winningest, borghese, sfsr, cura, enjoyment, pensacola, boogie, inserting,
# Nearest to or: rables, nilotic, hexameter, shrublands, recognizably, kathryn, unsafe, conch,
# Nearest to his: pled, demarco, flintlock, estonians, livia, wayne, tissues, internecine,
# Nearest to eight: widows, teborg, impacting, extravagance, malay, iraqis, academy, appellant,
# Nearest to so: lucky, shadow, strenuous, dialectal, eaton, digitization, lie, attach,
# Nearest to six: importing, yakko, megaliths, xo, cervix, khufu, probus, anaesthetic,
# Average loss at step 2000: 4.370414
# Average loss at step 4000: 3.865020
# Average loss at step 6000: 3.787106
# Average loss at step 8000: 3.687177
# Average loss at step 10000: 3.617005
# Nearest to its: the, his, their, vulva, her, some, ancients, strategos,
# Nearest to b: d, crossroads, sportswriters, norfolk, frets, reflection, qq, chariot,
# Nearest to five: eight, six, three, seven, four, nine, two, zero,
# Nearest to the: this, a, his, its, an, each, s, dq,
# Nearest to two: three, four, five, six, eight, nine, seven, one,
# Nearest to were: are, was, have, be, is, been, marsalis, emergency,
# Nearest to be: have, been, become, was, is, dnieper, were, eagle,
# Nearest to while: geographers, electrocution, semiconductor, if, colossians, tangled, warplanes, weren,
# Nearest to they: he, we, you, buenos, giancana, not, it, wojty,
# Nearest to see: dignity, applied, lfheim, assertions, oldsmobile, last, breathe, is,
# Nearest to of: in, for, enjoyment, winningest, national, and, radiating, fornication,
# Nearest to or: and, talmadge, knocks, bawdy, epictetus, than, coordinate, kos,
# Nearest to his: their, the, her, its, dull, plankton, s, lovers,
# Nearest to eight: nine, six, four, five, seven, three, zero, two,
# Nearest to so: alike, supercomputing, alkanes, emerald, recent, acquiesced, literals, alai,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Average loss at step 12000: 3.602600
# Average loss at step 14000: 3.577193
# Average loss at step 16000: 3.412922
# Average loss at step 18000: 3.455770
# Average loss at step 20000: 3.539135
# Nearest to its: their, the, his, her, axioms, some, ers, ancients,
# Nearest to b: d, norfolk, chicanos, massoud, gymnosperms, henotheism, qq, gerrymander,
# Nearest to five: six, three, four, seven, eight, two, zero, nine,
# Nearest to the: its, their, his, this, a, any, each, an,
# Nearest to two: three, five, four, six, eight, seven, one, zero,
# Nearest to were: are, was, had, have, is, be, hyperinsulinism, by,
# Nearest to be: have, been, by, was, were, become, is, follow,
# Nearest to while: geographers, if, although, colossians, with, negative, electrocution, semiconductor,
# Nearest to they: we, he, you, there, who, it, she, not,
# Nearest to see: breathe, oldsmobile, dignity, tobias, boethius, known, questioner, greed,
# Nearest to of: enjoyment, for, original, ztas, in, including, monumental, national,
# Nearest to or: and, than, with, but, photoelectric, resign, attainder, centimetre,
# Nearest to his: their, her, its, the, protects, strategos, plankton, volition,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to so: alike, comically, quaestor, alkanes, emerald, recent, statement, described,
# Nearest to six: eight, four, nine, five, seven, three, two, zero,
# Average loss at step 22000: 3.501771
# Average loss at step 24000: 3.487727
# Average loss at step 26000: 3.482450
# Average loss at step 28000: 3.482778
# Average loss at step 30000: 3.505364
# Nearest to its: their, the, his, her, ers, axioms, ancients, unending,
# Nearest to b: d, taverns, norfolk, contae, lem, glaciation, massoud, solicitation,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to the: its, their, his, dq, a, commutative, sanchez, many,
# Nearest to two: four, three, five, eight, one, six, seven, nine,
# Nearest to were: are, was, have, had, been, hyperinsulinism, those, be,
# Nearest to be: been, have, was, is, dnieper, were, reader, are,
# Nearest to while: although, but, if, bilbo, though, modernize, when, with,
# Nearest to they: we, you, he, there, it, who, these, not,
# Nearest to see: breathe, references, boethius, perk, crunch, youssef, do, cortisol,
# Nearest to of: in, measurable, vah, brook, winningest, enjoyment, original, including,
# Nearest to or: and, than, dubois, wallachia, nor, volk, mitsubishi, but,
# Nearest to his: her, their, its, the, s, dogmatically, protects, my,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to so: alike, statement, alkanes, quaestor, it, comically, hibernation, claim,
# Nearest to six: eight, nine, four, seven, five, three, zero, two,
# Average loss at step 32000: 3.507605
# Average loss at step 34000: 3.497425
# Average loss at step 36000: 3.456527
# Average loss at step 38000: 3.301372
# Average loss at step 40000: 3.428546
# Nearest to its: their, his, her, the, spoons, axioms, rumor, phase,
# Nearest to b: d, c, reflection, matejko, antiquities, shapeshifting, UNK, trios,
# Nearest to five: seven, four, six, three, eight, two, nine, zero,
# Nearest to the: its, their, any, his, a, this, each, another,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to were: are, have, was, had, be, been, these, being,
# Nearest to be: have, been, were, was, is, dnieper, reader, become,
# Nearest to while: although, when, if, but, before, though, however, modernize,
# Nearest to they: we, you, he, there, it, she, not, these,
# Nearest to see: references, boethius, include, includes, missourians, known, greed, flavors,
# Nearest to of: in, from, like, ztas, for, vah, original, morrill,
# Nearest to or: and, than, recommending, wallachia, tess, grained, dubois, nor,
# Nearest to his: their, her, its, the, my, s, your, dogmatically,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to so: alike, statement, it, sandwiched, middleton, hibernation, alkanes, claim,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Average loss at step 42000: 3.435387
# Average loss at step 44000: 3.451434
# Average loss at step 46000: 3.452638
# Average loss at step 48000: 3.356749
# Average loss at step 50000: 3.382244
# Nearest to its: their, his, the, her, axioms, phase, rumor, spoons,
# Nearest to b: d, shapeshifting, c, shattuck, crewmen, r, infants, detects,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to the: its, their, a, any, his, some, plankton, mnemonics,
# Nearest to two: three, four, one, six, five, eight, seven, nine,
# Nearest to were: are, have, was, had, been, be, those, is,
# Nearest to be: have, been, become, was, were, dnieper, being, reader,
# Nearest to while: when, although, however, after, though, if, but, before,
# Nearest to they: we, he, there, you, she, it, who, gays,
# Nearest to see: include, references, missourians, crunch, includes, monastics, undergraduate, ulrich,
# Nearest to of: in, enjoyment, brook, from, autumnal, and, accumulator, winningest,
# Nearest to or: and, than, jekyll, unction, neum, roo, mitsubishi, accredited,
# Nearest to his: her, their, its, my, the, your, s, him,
# Nearest to eight: six, nine, seven, four, three, five, zero, two,
# Nearest to so: alike, hibernation, yakovlev, note, kylie, too, middleton, berle,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Average loss at step 52000: 3.438192
# Average loss at step 54000: 3.423190
# Average loss at step 56000: 3.437645
# Average loss at step 58000: 3.398548
# Average loss at step 60000: 3.394043
# Nearest to its: their, his, her, the, examines, spoons, several, cholas,
# Nearest to b: d, c, shapeshifting, r, reflection, maverick, f, p,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to the: their, its, this, a, empties, some, any, comorian,
# Nearest to two: three, four, five, eight, six, one, seven, zero,
# Nearest to were: are, was, have, had, been, those, be, while,
# Nearest to be: been, become, dnieper, reader, are, have, was, were,
# Nearest to while: although, when, though, before, after, if, troop, however,
# Nearest to they: we, there, you, he, she, it, these, not,
# Nearest to see: include, list, references, includes, crunch, can, missourians, undergraduate,
# Nearest to of: in, for, same, including, winningest, autumnal, although, like,
# Nearest to or: and, than, minardi, bestseller, immoral, desai, neum, falcon,
# Nearest to his: her, their, its, my, dogmatically, your, adventist, the,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to so: too, statement, hibernation, note, operatives, argue, alike, hammers,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Average loss at step 62000: 3.241609
# Average loss at step 64000: 3.254940
# Average loss at step 66000: 3.400317
# Average loss at step 68000: 3.396741
# Average loss at step 70000: 3.359861
# Nearest to its: their, his, the, her, examines, several, rumor, phase,
# Nearest to b: d, r, shapeshifting, f, c, reflection, unveils, infants,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to the: its, their, a, any, this, these, another, some,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to were: are, was, have, had, be, been, interconnection, although,
# Nearest to be: been, become, were, is, have, was, are, being,
# Nearest to while: although, though, before, after, when, if, however, but,
# Nearest to they: we, there, he, you, it, she, gays, these,
# Nearest to see: include, list, references, but, can, missourians, crunch, undergraduate,
# Nearest to of: including, ztas, enjoyment, and, include, original, arnauld, in,
# Nearest to or: and, than, while, any, quintessentially, the, inertial, minardi,
# Nearest to his: her, their, its, my, adventist, dogmatically, your, the,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to so: hibernation, too, operatives, hammers, thus, nothing, statement, sweetener,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Average loss at step 72000: 3.373277
# Average loss at step 74000: 3.349461
# Average loss at step 76000: 3.322231
# Average loss at step 78000: 3.354329
# Average loss at step 80000: 3.376338
# Nearest to its: their, his, her, the, our, phase, your, affonso,
# Nearest to b: d, c, r, antiquities, reflection, shapeshifting, parenthesis, detects,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to the: its, their, this, his, gallatin, empties, a, canaveral,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to were: are, had, was, have, been, those, became, hyperinsulinism,
# Nearest to be: been, have, become, being, were, refer, are, is,
# Nearest to while: although, though, after, when, before, or, however, and,
# Nearest to they: we, he, there, you, she, it, these, not,
# Nearest to see: include, references, according, list, external, links, austrians, but,
# Nearest to of: including, in, hyginus, original, enjoyment, ztas, actinide, lilac,
# Nearest to or: and, than, while, wallachia, ro, although, recommending, teborg,
# Nearest to his: her, their, its, my, your, the, constrain, personal,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to so: hammers, hibernation, ground, too, then, ud, beyond, when,
# Nearest to six: five, four, eight, seven, three, nine, two, zero,
# Average loss at step 82000: 3.407213
# Average loss at step 84000: 3.411374
# Average loss at step 86000: 3.388731
# Average loss at step 88000: 3.355208
# Average loss at step 90000: 3.368865
# Nearest to its: their, his, her, the, our, your, some, hearted,
# Nearest to b: d, c, r, reflection, shapeshifting, matejko, parenthesis, f,
# Nearest to five: four, seven, eight, three, six, nine, two, zero,
# Nearest to the: its, empties, their, this, his, a, sanchez, canaveral,
# Nearest to two: three, five, four, six, seven, one, eight, nine,
# Nearest to were: are, had, was, have, while, those, although, been,
# Nearest to be: have, been, become, being, was, tries, is, dnieper,
# Nearest to while: although, though, after, when, before, were, during, where,
# Nearest to they: we, he, there, you, she, it, who, hennecke,
# Nearest to see: references, list, joey, include, but, isostatic, evi, equiv,
# Nearest to of: including, for, in, miata, mellitus, during, under, from,
# Nearest to or: and, than, recommending, including, while, unction, horrifying, meteor,
# Nearest to his: her, their, its, my, your, the, s, strategos,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to so: hammers, before, too, iskra, ground, hibernation, thus, ud,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Average loss at step 92000: 3.396985
# Average loss at step 94000: 3.253319
# Average loss at step 96000: 3.359256
# Average loss at step 98000: 3.248091
# Average loss at step 100000: 3.357300
# Nearest to its: their, his, her, the, coffins, phase, gonorrhea, affonso,
# Nearest to b: d, matejko, chicanos, c, glaciation, excitation, valuables, cdot,
# Nearest to five: four, seven, six, eight, three, zero, two, nine,
# Nearest to the: their, its, his, your, a, this, her, some,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to were: are, was, have, those, these, had, including, be,
# Nearest to be: been, become, have, being, are, tries, is, produce,
# Nearest to while: when, although, though, after, before, and, where, however,
# Nearest to they: we, he, there, you, she, it, quintet, these,
# Nearest to see: references, list, wiecino, ulrich, rw, evi, joey, includes,
# Nearest to of: including, in, lindow, hyginus, like, and, winningest, from,
# Nearest to or: and, than, recommending, affront, any, falcon, while, geologic,
# Nearest to his: her, their, my, its, your, the, s, our,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to so: too, thus, hibernation, hammers, then, gaming, beyond, ud,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ context_window target context_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[context_window]
        target = context_window
        k = 0
        for j in range(span):
            if j != context_window:
                batch[i][k] = buffer[j]
                k = k + 1
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for idx in range(8):
        print('    batch %d: %s' % (idx, [reverse_dictionary[bi] for bi in batch[idx]]))
        print('    label %d: %s' % (idx, reverse_dictionary[labels[idx, 0]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with context_window = 2:
#     batch 0: ['anarchism', 'originated', 'a', 'term']
#     label 0: as
#     batch 1: ['originated', 'as', 'term', 'of']
#     label 1: a
#     batch 2: ['as', 'a', 'of', 'abuse']
#     label 2: term
#     batch 3: ['a', 'term', 'abuse', 'first']
#     label 3: of
#     batch 4: ['term', 'of', 'first', 'used']
#     label 4: abuse
#     batch 5: ['of', 'abuse', 'used', 'against']
#     label 5: first
#     batch 6: ['abuse', 'first', 'against', 'early']
#     label 6: used
#     batch 7: ['first', 'used', 'early', 'working']
#     label 7: against
#
# with context_window = 4:
#     batch 0: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label 0: term
#     batch 1: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label 1: of
#     batch 2: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label 2: abuse
#     batch 3: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label 3: first
#     batch 4: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label 4: used
#     batch 5: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label 5: against
#     batch 6: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label 6: early
#     batch 7: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label 7: working

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # This is the alternative to skip_window, however we don't need the skip steps here,
                   # since all words are always included
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Get the sum of the embeddings for the each entry
    embedding_context = tf.reduce_sum(embed, 1)
     
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedding_context,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.884085
# Nearest to other: neuch, resistance, hippopotamus, photolithography, sheriff, delusion, deutschland, dionysius,
# Nearest to between: dilute, cock, barbaric, proponent, unilaterally, usn, princesses, outage,
# Nearest to is: adored, reap, braxton, siemens, preterite, citizen, reginae, satchmo,
# Nearest to more: lyell, matlab, miss, fearing, turnovers, canola, powered, wednesday,
# Nearest to who: nominate, compilations, couple, related, scuola, pellets, slab, clearly,
# Nearest to on: mammalia, salic, embellishment, recall, spectacle, trochaic, cara, appletalk,
# Nearest to over: deleted, num, marshy, suckling, apostate, bx, cour, talons,
# Nearest to which: fatal, penetrating, vida, beyond, heartland, satisfactorily, polskiej, tupolev,
# Nearest to state: broadbent, courts, asperger, jehoiachin, photosynthetic, debilitating, landholdings, bouncer,
# Nearest to of: philippines, natal, inhibition, augustin, montparnasse, attaining, enchantments, damietta,
# Nearest to see: ecuadorian, franchises, sheet, henning, modeling, but, magnetometer, steyr,
# Nearest to states: haeckel, irina, avec, davison, vail, egyptian, ghosting, honeycomb,
# Nearest to have: physicists, crosses, lucio, consequence, lanzarote, shaikh, zuse, popularization,
# Nearest to in: rcn, catapult, equality, fortresses, embarked, club, adept, unfulfilled,
# Nearest to zero: canadians, unaccompanied, accountant, brunner, wines, eponym, azimuth, petersburg,
# Nearest to american: annexation, vacation, bylaws, stability, extended, adoration, degeneracy, purport,
# Average loss at step 2000: 4.098270
# Average loss at step 4000: 3.565151
# Average loss at step 6000: 3.389364
# Average loss at step 8000: 3.245773
# Average loss at step 10000: 3.177640
# Nearest to other: americans, extradition, alkane, many, lift, these, slowdown, advocate,
# Nearest to between: cock, with, fulfills, recipes, from, multistage, usn, supposing,
# Nearest to is: was, has, are, cubana, showed, were, be, ordovician,
# Nearest to more: most, less, fearing, rather, thirtieth, holst, haganah, auditum,
# Nearest to who: he, disappear, which, they, endemic, she, novelization, compilations,
# Nearest to on: in, through, upon, exuberant, perrin, optimization, netbsd, coprocessor,
# Nearest to over: socializing, marshy, deleted, bcpl, rust, pilgrimage, henderson, albigensian,
# Nearest to which: that, this, it, who, also, esquerra, mutually, cells,
# Nearest to state: jehoiachin, pedantic, courts, weasels, broadbent, debilitating, wehrmacht, hal,
# Nearest to of: for, canoe, enthusiasts, lauter, fay, minefields, dorado, iole,
# Nearest to see: putney, henning, canaria, sheet, ferguson, landowners, hottest, but,
# Nearest to states: egyptian, avec, rhodes, nations, aneurin, caring, vail, kul,
# Nearest to have: had, has, be, were, are, withhold, having, unpredictability,
# Nearest to in: at, on, from, within, for, with, through, near,
# Nearest to zero: eight, five, four, seven, nine, six, three, two,
# Nearest to american: pancho, flushed, bundaberg, delight, persistence, canadian, bylaws, british,
# Average loss at step 12000: 3.199353
# Average loss at step 14000: 3.154210
# Average loss at step 16000: 3.181892
# Average loss at step 18000: 3.126037
# Average loss at step 20000: 2.992237
# Nearest to other: different, including, european, various, equites, lez, shadowrun, channelled,
# Nearest to between: with, checkerboard, fulfills, recipes, fermentable, supposing, cock, multistage,
# Nearest to is: was, has, are, be, became, were, does, alkaline,
# Nearest to more: less, most, rather, very, thirtieth, highly, holst, exiling,
# Nearest to who: he, which, often, she, they, also, that, ailments,
# Nearest to on: upon, optimization, through, werth, darkest, paedophilia, misnomer, mammalia,
# Nearest to over: pump, socializing, off, into, deleted, performances, caliber, apostate,
# Nearest to which: that, this, also, who, usually, there, it, often,
# Nearest to state: pedantic, judicial, jehoiachin, recover, isosceles, courts, weasels, leibniz,
# Nearest to of: canoe, sportscaster, interglacial, for, seaway, vernal, pons, korca,
# Nearest to see: muscular, called, hydra, putney, canaria, henning, yams, but,
# Nearest to states: nations, countries, aneurin, scenes, wollaston, egyptian, irina, avec,
# Nearest to have: had, has, were, be, are, include, accommodation, unpredictability,
# Nearest to in: during, within, at, manipulations, berb, since, nationalised, pre,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to american: flushed, british, rim, english, memo, bundaberg, australian, canadian,
# Average loss at step 22000: 3.077408
# Average loss at step 24000: 3.038708
# Average loss at step 26000: 3.004567
# Average loss at step 28000: 3.027619
# Average loss at step 30000: 3.008245
# Nearest to other: different, various, lez, others, fein, loyalists, equites, many,
# Nearest to between: among, with, recipes, secessionist, over, dmca, fermentable, checkerboard,
# Nearest to is: was, has, are, became, remains, provides, be, makes,
# Nearest to more: less, rather, most, highly, very, outdoor, thirtieth, longer,
# Nearest to who: which, he, already, she, also, they, endemic, still,
# Nearest to on: upon, through, in, tutsi, paedophilia, about, optimization, sed,
# Nearest to over: off, through, into, up, pump, between, lengthening, dannebrog,
# Nearest to which: that, this, who, also, however, trianon, what, these,
# Nearest to state: pedantic, recover, government, jehoiachin, courts, odors, argumentative, judicial,
# Nearest to of: canoe, in, like, sportscaster, including, romulus, interglacial, from,
# Nearest to see: but, canaria, called, albrecht, lascaris, gibraltarians, putney, provisioning,
# Nearest to states: nations, countries, kingdom, aneurin, avec, canada, acclaim, egyptian,
# Nearest to have: had, has, were, are, include, having, be, refer,
# Nearest to in: within, during, on, from, telo, since, mailbox, at,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to american: canadian, flushed, british, indian, european, australian, throttle, chessboard,
# Average loss at step 32000: 2.823036
# Average loss at step 34000: 2.953026
# Average loss at step 36000: 2.946694
# Average loss at step 38000: 2.944368
# Average loss at step 40000: 2.932000
# Nearest to other: various, different, others, seventeenth, including, fein, containing, equites,
# Nearest to between: among, with, over, secessionist, within, checkerboard, recipes, hips,
# Nearest to is: was, has, are, becomes, does, eia, provides, requires,
# Nearest to more: less, most, very, highly, rather, thirtieth, smaller, infections,
# Nearest to who: he, often, which, they, still, she, frf, actually,
# Nearest to on: upon, through, werth, afflicted, within, during, deafness, paedophilia,
# Nearest to over: off, within, between, through, pump, dannebrog, into, affinity,
# Nearest to which: that, this, usually, also, what, who, actually, often,
# Nearest to state: pedantic, government, recover, city, licentious, surfing, jehoiachin, isosceles,
# Nearest to of: although, including, sportscaster, gop, uncollected, pons, iole, however,
# Nearest to see: references, bund, accommodated, albrecht, include, lascaris, wakizashi, canaria,
# Nearest to states: nations, kingdom, countries, aneurin, corvettes, kul, scenes, studies,
# Nearest to have: had, has, were, are, be, having, include, refer,
# Nearest to in: within, during, haldeman, from, throughout, nde, impressionism, among,
# Nearest to zero: five, six, four, seven, eight, three, nine, two,
# Nearest to american: canadian, british, european, flushed, chessboard, americans, japanese, bulgarian,
# Average loss at step 42000: 2.950435
# Average loss at step 44000: 2.957338
# Average loss at step 46000: 2.909697
# Average loss at step 48000: 2.863355
# Average loss at step 50000: 2.843798
# Nearest to other: various, others, different, funneled, underdog, warhol, equites, macedonian,
# Nearest to between: among, with, checkerboard, secessionist, over, hips, fermentable, dmca,
# Nearest to is: was, has, remains, are, be, became, refers, becomes,
# Nearest to more: less, most, very, rather, highly, thirtieth, larger, higher,
# Nearest to who: he, she, frf, also, which, already, still, smith,
# Nearest to on: upon, in, at, during, tutsi, within, exuberant, through,
# Nearest to over: off, across, within, between, into, matteo, out, agassi,
# Nearest to which: that, this, what, usually, also, these, actually, who,
# Nearest to state: pedantic, city, government, bittering, yorkers, states, recover, courts,
# Nearest to of: medi, in, for, sportscaster, jujutsu, conjectural, including, gbu,
# Nearest to see: includes, references, but, lavish, morgue, include, muscular, lascaris,
# Nearest to states: nations, countries, kingdom, us, aneurin, studies, scenes, airlines,
# Nearest to have: had, has, were, include, be, having, are, contain,
# Nearest to in: during, within, at, on, from, throughout, of, actual,
# Nearest to zero: seven, five, four, six, eight, nine, three, two,
# Nearest to american: canadian, british, and, english, japanese, italian, australian, german,
# Average loss at step 52000: 2.885006
# Average loss at step 54000: 2.866784
# Average loss at step 56000: 2.861485
# Average loss at step 58000: 2.747271
# Average loss at step 60000: 2.835129
# Nearest to other: various, others, equites, funneled, individual, underdog, those, different,
# Nearest to between: among, with, over, within, secessionist, checkerboard, across, towards,
# Nearest to is: was, has, are, becomes, provides, seems, remains, became,
# Nearest to more: less, most, very, rather, highly, greater, longer, higher,
# Nearest to who: she, he, often, frf, still, smith, already, subtrees,
# Nearest to on: upon, through, within, under, in, at, during, gabab,
# Nearest to over: across, between, into, within, through, matteo, off, yahya,
# Nearest to which: that, what, this, usually, also, actually, these, where,
# Nearest to state: pedantic, government, yorkers, states, bittering, courts, recover, whipping,
# Nearest to of: including, sportscaster, although, in, include, tenacious, montague, uninterrupted,
# Nearest to see: includes, include, references, bund, but, muscular, lascaris, according,
# Nearest to states: nations, kingdom, countries, corvettes, kul, state, provinces, aneurin,
# Nearest to have: had, has, are, having, be, provide, were, include,
# Nearest to in: during, within, at, among, on, haldeman, under, from,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to american: canadian, british, australian, indian, german, japanese, italian, pancho,
# Average loss at step 62000: 2.837202
# Average loss at step 64000: 2.773208
# Average loss at step 66000: 2.760171
# Average loss at step 68000: 2.707871
# Average loss at step 70000: 2.777937
# Nearest to other: various, equites, others, older, individual, funneled, underdog, different,
# Nearest to between: among, within, with, over, from, checkerboard, towards, across,
# Nearest to is: was, has, remains, includes, are, provides, does, contains,
# Nearest to more: less, most, very, greater, highly, rather, longer, higher,
# Nearest to who: he, she, they, which, actually, smith, frf, already,
# Nearest to on: upon, in, under, at, during, within, around, through,
# Nearest to over: across, off, between, through, within, pump, into, traffic,
# Nearest to which: that, also, this, usually, what, typically, instead, who,
# Nearest to state: pedantic, government, states, city, manatee, bittering, recover, yorkers,
# Nearest to of: in, medi, sportscaster, including, formalist, kibo, iole, uninterrupted,
# Nearest to see: references, includes, lascaris, saw, ruble, but, refer, include,
# Nearest to states: nations, kingdom, provinces, us, kul, countries, rammstein, state,
# Nearest to have: had, has, having, contain, include, refer, provide, be,
# Nearest to in: during, within, on, throughout, under, since, until, berb,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to american: canadian, australian, british, german, italian, english, pancho, indian,
# Average loss at step 72000: 2.794943
# Average loss at step 74000: 2.644724
# Average loss at step 76000: 2.797951
# Average loss at step 78000: 2.824445
# Average loss at step 80000: 2.778514
# Nearest to other: various, individual, several, many, equites, underdog, others, premiers,
# Nearest to between: among, within, with, secessionist, from, hips, checkerboard, across,
# Nearest to is: was, has, are, becomes, remains, became, includes, makes,
# Nearest to more: less, very, most, rather, greater, quite, highly, higher,
# Nearest to who: he, she, subtrees, actually, often, already, frf, which,
# Nearest to on: upon, in, during, around, concerning, gabab, under, at,
# Nearest to over: across, through, around, off, throughout, pump, whichever, traffic,
# Nearest to which: that, this, but, what, these, instead, also, usually,
# Nearest to state: pedantic, city, states, government, yorkers, manatee, republic, courts,
# Nearest to of: despite, including, in, damietta, uncanny, and, iole, sportscaster,
# Nearest to see: include, muscular, includes, references, saw, but, lascaris, wto,
# Nearest to states: nations, kingdom, countries, provinces, rammstein, state, districts, kul,
# Nearest to have: had, has, are, were, having, include, contain, provide,
# Nearest to in: during, within, at, on, throughout, near, under, from,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to american: canadian, australian, british, italian, english, irish, african, german,
# Average loss at step 82000: 2.664718
# Average loss at step 84000: 2.771921
# Average loss at step 86000: 2.734507
# Average loss at step 88000: 2.754039
# Average loss at step 90000: 2.734833
# Nearest to other: various, equites, individual, several, different, older, others, astor,
# Nearest to between: among, with, within, secessionist, checkerboard, hips, ensign, fermentable,
# Nearest to is: was, has, provides, remains, are, becomes, contains, became,
# Nearest to more: less, most, very, greater, rather, quite, highly, too,
# Nearest to who: actually, he, she, often, subtrees, they, initially, still,
# Nearest to on: upon, in, through, concerning, within, gabab, capitan, at,
# Nearest to over: across, off, around, about, through, pump, throughout, morrill,
# Nearest to which: that, this, what, also, typically, actually, instead, usually,
# Nearest to state: pedantic, city, government, manatee, territory, republican, yorkers, national,
# Nearest to of: sportscaster, including, for, nac, gop, botched, despite, montague,
# Nearest to see: include, references, includes, muscular, lascaris, morgue, but, provisioning,
# Nearest to states: nations, kingdom, countries, provinces, districts, kul, corvettes, airlines,
# Nearest to have: had, has, were, are, contain, having, be, produce,
# Nearest to in: during, within, on, throughout, at, near, through, including,
# Nearest to zero: six, five, seven, eight, four, nine, three, two,
# Nearest to american: canadian, australian, british, french, african, italian, indian, european,
# Average loss at step 92000: 2.680634
# Average loss at step 94000: 2.724662
# Average loss at step 96000: 2.701208
# Average loss at step 98000: 2.363450
# Average loss at step 100000: 2.405013
# Nearest to other: various, others, equites, individual, funneled, remaining, premiers, contemporary,
# Nearest to between: with, among, within, checkerboard, across, secessionist, hips, ensign,
# Nearest to is: was, remains, has, becomes, became, seems, are, requires,
# Nearest to more: less, most, very, rather, greater, longer, worse, quite,
# Nearest to who: often, actually, also, he, which, never, gonzalo, she,
# Nearest to on: upon, at, concerning, tutsi, celts, werth, through, around,
# Nearest to over: across, off, around, traffic, palomar, morrill, within, throughout,
# Nearest to which: that, what, this, actually, instead, also, typically, usually,
# Nearest to state: pedantic, states, government, city, republic, yorkers, territory, manatee,
# Nearest to of: sportscaster, kibo, uncanny, medi, from, despite, including, gop,
# Nearest to see: references, includes, include, external, muscular, list, make, albrecht,
# Nearest to states: nations, kingdom, us, provinces, countries, state, aneurin, airlines,
# Nearest to have: had, has, having, contain, were, are, include, be,
# Nearest to in: during, within, near, at, throughout, berb, outside, around,
# Nearest to zero: six, five, four, seven, eight, three, nine, two,
# Nearest to american: canadian, australian, british, english, german, italian, irish, cartwright,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
