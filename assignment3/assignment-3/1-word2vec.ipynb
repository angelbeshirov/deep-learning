# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.199728
# Nearest to may: splitting, microtubule, shared, for, perpetrator, quaternions, banish, typologically,
# Nearest to and: shrouded, corrino, ladies, wearer, dismissed, martinique, occasionally, undeserved,
# Nearest to state: synagogue, interspersed, homework, materialize, beatle, antitrust, ornaments, conciliation,
# Nearest to american: fijian, microgravity, printing, wolfhounds, bra, aaa, bilabial, gail,
# Nearest to a: crowds, anemia, sergeant, commemoration, chronic, mechanized, gina, magenta,
# Nearest to these: consented, adin, kotzebue, dialects, ignite, westland, significand, interrogation,
# Nearest to in: pax, inscribed, serb, escap, ecumenism, adhesive, magen, pancakes,
# Nearest to first: fairfax, outposts, spreadsheets, underdeveloped, bin, loonie, chants, assyrians,
# Nearest to be: gatherers, regolith, flooding, grotesque, fitted, jocular, gala, paradise,
# Nearest to over: ordo, term, incomparable, racine, gheorghe, forbidden, ndnis, rosetta,
# Nearest to th: tunny, indie, removing, signalled, contraception, ky, machining, conference,
# Nearest to used: lubricated, cylindrical, utilising, toole, tropospheric, pearse, divorcing, larwood,
# Nearest to use: imperceptible, furigana, yorke, capillaries, criswell, ladd, fleeting, pickering,
# Nearest to were: nacional, subtype, geared, superclusters, notoriety, adolescents, lyre, marduk,
# Nearest to by: taekwondo, origination, area, harum, lot, gottlob, invocations, peta,
# Nearest to s: szasz, effects, request, kathmandu, circuits, definability, prohibits, comecon,
# Average loss at step 2000: 4.370840
# Average loss at step 4000: 3.875120
# Average loss at step 6000: 3.791283
# Average loss at step 8000: 3.689446
# Average loss at step 10000: 3.614456
# Nearest to may: could, can, would, microtubule, heorot, couldn, arcueil, biham,
# Nearest to and: or, s, in, but, kou, which, tedious, american,
# Nearest to state: materialize, synagogue, scrip, homework, tarzan, beatle, decoy, minima,
# Nearest to american: fijian, printing, underworld, british, convertible, and, superceded, picts,
# Nearest to a: the, this, guanine, perception, dfts, his, its, holiness,
# Nearest to these: adin, dialects, aldus, bahrain, many, interrogation, straczynski, kotzebue,
# Nearest to in: of, on, from, at, within, with, for, and,
# Nearest to first: only, during, fairfax, restraints, following, outposts, twelve, brzezinski,
# Nearest to be: have, was, is, signified, aragonese, parke, been, qed,
# Nearest to over: term, topics, ordo, gheorghe, dachshunds, mainstream, wiktionary, shires,
# Nearest to th: tunny, eldridge, machining, removing, memorization, zero, cooper, ciphertexts,
# Nearest to used: tipping, described, cylindrical, lubricated, hasidim, uralic, ultimatum, heather,
# Nearest to use: imperceptible, bihar, postel, cacm, injuring, criswell, freda, capillaries,
# Nearest to were: are, was, nacional, adolescents, templates, dialog, have, formosa,
# Nearest to by: including, been, was, as, thabit, dis, tramway, secured,
# Nearest to s: his, and, humanae, the, was, or, wanna, chronometer,
# Average loss at step 12000: 3.610218
# Average loss at step 14000: 3.570205
# Average loss at step 16000: 3.410822
# Average loss at step 18000: 3.456814
# Average loss at step 20000: 3.544761
# Nearest to may: can, could, would, will, should, must, might, microtubule,
# Nearest to and: or, from, in, kou, for, but, kilobit, of,
# Nearest to state: minima, tarzan, homework, council, eris, moods, profile, broadening,
# Nearest to american: british, french, fijian, underworld, printing, devotes, falla, rastafari,
# Nearest to a: the, this, guanine, any, visigoth, newcomer, orange, agatha,
# Nearest to these: many, some, all, aldus, which, other, dialects, adin,
# Nearest to in: at, on, from, and, by, for, with, of,
# Nearest to first: following, twelve, fairfax, bursa, kali, second, grant, recoveries,
# Nearest to be: have, been, is, by, was, being, treeless, were,
# Nearest to over: dachshunds, enthusiastically, topics, idiosyncrasies, mainstream, extraterrestrial, forward, bloch,
# Nearest to th: eldridge, memorization, machining, removing, worthwhile, elaborately, kicker, ciphertexts,
# Nearest to used: tipping, described, viewed, known, raised, cylindrical, referred, dhaka,
# Nearest to use: injuring, most, rana, cacm, criswell, imperceptible, swede, symbolism,
# Nearest to were: are, was, have, had, is, by, tinted, templates,
# Nearest to by: be, been, in, were, for, from, including, thabit,
# Nearest to s: chronometer, reuter, the, carcinogen, terrifying, squeezed, and, cidre,
# Average loss at step 22000: 3.507001
# Average loss at step 24000: 3.487588
# Average loss at step 26000: 3.485998
# Average loss at step 28000: 3.477965
# Average loss at step 30000: 3.501138
# Nearest to may: can, would, could, will, must, should, might, biham,
# Nearest to and: or, but, in, who, of, breve, however, by,
# Nearest to state: eris, council, tarzan, moods, minima, materialize, sayfawa, profile,
# Nearest to american: british, french, english, picts, italian, german, fijian, convertible,
# Nearest to a: any, another, the, no, beneficial, bryce, lucille, guanine,
# Nearest to these: some, many, several, they, such, which, all, aldus,
# Nearest to in: during, at, of, on, under, within, and, until,
# Nearest to first: second, last, twelve, grant, fairfax, next, recoveries, same,
# Nearest to be: been, have, become, is, learn, refer, reductionism, are,
# Nearest to over: dachshunds, enthusiastically, earthworm, mainstream, extraterrestrial, bloch, forward, idiosyncrasies,
# Nearest to th: six, memorization, nineteenth, bc, kicker, eldridge, crtc, machining,
# Nearest to used: described, given, known, found, viewed, tipping, available, considered,
# Nearest to use: advent, injuring, swede, smoother, rana, xviii, need, appointments,
# Nearest to were: are, was, have, been, had, wettest, including, being,
# Nearest to by: under, da, were, as, clearly, was, in, castration,
# Nearest to s: his, uncollected, reuter, etymologically, beige, akademie, shipping, strawberries,
# Average loss at step 32000: 3.500802
# Average loss at step 34000: 3.497397
# Average loss at step 36000: 3.452816
# Average loss at step 38000: 3.300952
# Average loss at step 40000: 3.429411
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to and: or, but, overtime, in, including, while, hk, laredo,
# Nearest to state: tarzan, council, government, eris, city, profile, moods, retardation,
# Nearest to american: british, french, german, devotes, italian, rastafari, australian, english,
# Nearest to a: the, visigoth, another, any, or, osce, preacher, no,
# Nearest to these: many, some, several, both, those, all, such, which,
# Nearest to in: during, of, and, icao, to, for, nukem, at,
# Nearest to first: second, last, next, fourth, grant, saiyan, twelve, recoveries,
# Nearest to be: been, have, was, is, being, octets, become, were,
# Nearest to over: dietary, clout, repulsed, extraterrestrial, theodoret, dachshunds, through, when,
# Nearest to th: memorization, bc, rd, nineteenth, eldridge, kicker, ad, mpv,
# Nearest to used: found, described, given, available, considered, referred, viewed, known,
# Nearest to use: swede, summations, filesystem, smoother, need, kettle, members, appointments,
# Nearest to were: are, have, was, had, being, including, been, wettest,
# Nearest to by: jamie, castration, as, chimera, tasso, neuro, be, plunkett,
# Nearest to s: his, ribbentrop, filmfour, her, squeezed, secreted, excretory, utilise,
# Average loss at step 42000: 3.433546
# Average loss at step 44000: 3.455530
# Average loss at step 46000: 3.455101
# Average loss at step 48000: 3.348273
# Average loss at step 50000: 3.388516
# Nearest to may: can, would, could, must, will, should, might, cannot,
# Nearest to and: or, but, including, while, s, interlingua, of, in,
# Nearest to state: council, retardation, moods, goat, profile, government, tarzan, eris,
# Nearest to american: french, british, devotes, indian, english, australian, italian, international,
# Nearest to a: another, the, any, orange, opteron, maris, guanine, regaining,
# Nearest to these: some, many, those, both, several, such, all, they,
# Nearest to in: during, since, within, from, on, of, between, and,
# Nearest to first: second, last, next, fourth, same, saiyan, semimajor, citizens,
# Nearest to be: been, have, become, being, was, were, signified, refer,
# Nearest to over: dachshunds, dietary, through, earthworm, repulsed, lately, mandibles, across,
# Nearest to th: ad, nineteenth, memorization, bc, rd, rosen, abominable, kicker,
# Nearest to used: known, described, available, seen, referred, viewed, written, applied,
# Nearest to use: swede, kettle, advent, gardener, poirot, eaters, summations, yeast,
# Nearest to were: are, was, have, had, been, wettest, templates, being,
# Nearest to by: under, with, neuro, interlingua, through, was, including, against,
# Nearest to s: whose, and, his, savior, basslines, interferometry, montr, benediction,
# Average loss at step 52000: 3.439816
# Average loss at step 54000: 3.424988
# Average loss at step 56000: 3.437162
# Average loss at step 58000: 3.396225
# Average loss at step 60000: 3.394194
# Nearest to may: can, would, could, must, will, should, might, cannot,
# Nearest to and: or, but, including, physiological, however, oic, window, in,
# Nearest to state: council, government, city, advancing, retardation, profile, nature, landless,
# Nearest to american: british, indian, devotes, french, italian, australian, international, german,
# Nearest to a: another, the, any, orange, every, ppt, agatha, opteron,
# Nearest to these: many, some, those, both, several, all, such, they,
# Nearest to in: within, during, of, until, on, with, since, into,
# Nearest to first: second, next, last, fourth, same, third, only, saiyan,
# Nearest to be: been, become, is, was, have, refer, being, are,
# Nearest to over: through, earthworm, dietary, lately, dachshunds, across, repulsed, alcor,
# Nearest to th: nineteenth, memorization, five, bc, st, six, ad, rd,
# Nearest to used: described, known, referred, available, seen, viewed, written, designed,
# Nearest to use: most, kettle, eaters, need, advent, role, appointments, swede,
# Nearest to were: are, was, have, had, wettest, been, including, those,
# Nearest to by: grossed, with, gottlob, be, through, clearly, neuro, from,
# Nearest to s: westeros, sacrificing, whose, cleaners, antonio, piercer, patristic, ribbentrop,
# Average loss at step 62000: 3.245424
# Average loss at step 64000: 3.257581
# Average loss at step 66000: 3.408986
# Average loss at step 68000: 3.396147
# Average loss at step 70000: 3.354917
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to and: or, but, while, than, overtime, courtyards, scrooge, darkest,
# Nearest to state: city, government, council, profile, eris, states, goat, ness,
# Nearest to american: british, indian, devotes, italian, australian, african, bethe, diaspora,
# Nearest to a: another, the, any, feline, enough, pleads, vero, jaeger,
# Nearest to these: many, some, such, those, fairness, several, they, various,
# Nearest to in: within, during, on, for, until, since, throughout, through,
# Nearest to first: second, next, last, fourth, same, best, third, entire,
# Nearest to be: been, become, is, were, being, have, are, was,
# Nearest to over: earthworm, converter, dietary, lately, dachshunds, through, repulsed, alcor,
# Nearest to th: nineteenth, bc, rd, third, ad, st, memorization, rosen,
# Nearest to used: known, available, referred, seen, designed, described, written, applied,
# Nearest to use: appointments, most, need, kettle, swede, species, eaters, dickinson,
# Nearest to were: are, was, have, had, be, wettest, been, lan,
# Nearest to by: through, clearly, was, gottlob, meritorious, superpower, in, tasso,
# Nearest to s: whose, reuter, piercer, asatru, sibylla, cirth, cheng, ribbentrop,
# Average loss at step 72000: 3.378029
# Average loss at step 74000: 3.348197
# Average loss at step 76000: 3.313503
# Average loss at step 78000: 3.357265
# Average loss at step 80000: 3.372718
# Nearest to may: can, could, will, would, might, must, should, cannot,
# Nearest to and: or, but, including, courtyards, than, while, brun, quarterback,
# Nearest to state: city, profile, council, goat, government, states, hokkaido, chabad,
# Nearest to american: british, indian, german, french, australian, devotes, bethe, international,
# Nearest to a: another, the, bryce, vero, mechanized, every, donkeys, batavians,
# Nearest to these: several, many, those, both, some, they, such, various,
# Nearest to in: on, during, within, until, at, since, galbraith, between,
# Nearest to first: second, last, next, fourth, same, third, best, only,
# Nearest to be: been, have, become, being, is, octets, refer, were,
# Nearest to over: earthworm, through, towards, dietary, across, about, alcor, repulsed,
# Nearest to th: bc, rd, ad, nineteenth, rosen, third, memorization, kicker,
# Nearest to used: known, referred, available, seen, applied, designed, described, written,
# Nearest to use: kettle, most, excite, appointments, need, filesystem, eaters, propagate,
# Nearest to were: are, was, had, have, being, been, wettest, those,
# Nearest to by: clearly, gottlob, neuro, newly, through, gould, nisibis, interphase,
# Nearest to s: whose, kitchener, piercer, ribbentrop, vms, gilbert, merrill, squeezed,
# Average loss at step 82000: 3.409227
# Average loss at step 84000: 3.407056
# Average loss at step 86000: 3.390566
# Average loss at step 88000: 3.354452
# Average loss at step 90000: 3.365770
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to and: or, but, while, including, courtyards, however, eleazar, in,
# Nearest to state: city, profile, council, colourless, therapy, government, carmel, hokkaido,
# Nearest to american: british, indian, french, german, italian, australian, irish, russian,
# Nearest to a: another, the, any, arxiv, visigoth, every, interceptor, crawling,
# Nearest to these: several, many, some, both, those, all, various, such,
# Nearest to in: during, within, under, with, between, on, of, sugarcubes,
# Nearest to first: second, last, next, fourth, same, best, third, oldest,
# Nearest to be: been, become, was, is, have, being, refer, lead,
# Nearest to over: earthworm, through, about, dietary, across, mandibles, between, around,
# Nearest to th: bc, rd, st, ad, nineteenth, fourth, one, rosen,
# Nearest to used: known, seen, referred, available, applied, designed, described, called,
# Nearest to use: most, filesystem, support, simulates, need, kettle, mercilessly, clarity,
# Nearest to were: are, had, have, was, while, although, yeasts, those,
# Nearest to by: through, from, during, under, for, while, grossed, when,
# Nearest to s: whose, his, michelle, kitchener, utilise, sclerosis, isbn, strawberries,
# Average loss at step 92000: 3.398584
# Average loss at step 94000: 3.254371
# Average loss at step 96000: 3.358546
# Average loss at step 98000: 3.248391
# Average loss at step 100000: 3.358022
# Nearest to may: can, could, must, should, would, might, will, cannot,
# Nearest to and: or, but, while, however, although, when, shutter, including,
# Nearest to state: city, profile, carmel, council, government, advancing, colourless, states,
# Nearest to american: british, indian, italian, french, australian, german, russian, english,
# Nearest to a: another, the, any, opteron, enough, usr, crawling, seaside,
# Nearest to these: several, many, some, various, all, those, different, were,
# Nearest to in: during, within, until, throughout, on, from, under, at,
# Nearest to first: second, next, last, fourth, third, same, seventh, final,
# Nearest to be: been, become, have, being, is, octets, try, refer,
# Nearest to over: through, earthworm, dietary, between, across, around, off, forward,
# Nearest to th: bc, rd, third, fourth, nineteenth, rosen, nd, ad,
# Nearest to used: referred, seen, available, applied, designed, known, found, defined,
# Nearest to use: filesystem, need, simulates, yeast, most, support, practice, swede,
# Nearest to were: are, have, was, these, had, those, although, templates,
# Nearest to by: gottlob, under, tatar, plunkett, without, through, interphase, against,
# Nearest to s: his, piercer, whose, kitchener, gilbert, michelle, nieuwe, alfred,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ context_window target context_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[context_window]
        target = context_window
        k = 0
        for j in range(span):
            if j != context_window:
                batch[i][k] = buffer[j]
                k = k + 1
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for idx in range(8):
        print('    batch %d: %s' % (idx, [reverse_dictionary[bi] for bi in batch[idx]]))
        print('    label %d: %s' % (idx, reverse_dictionary[labels[idx, 0]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with context_window = 2:
#     batch 0: ['anarchism', 'originated', 'a', 'term']
#     label 0: as
#     batch 1: ['originated', 'as', 'term', 'of']
#     label 1: a
#     batch 2: ['as', 'a', 'of', 'abuse']
#     label 2: term
#     batch 3: ['a', 'term', 'abuse', 'first']
#     label 3: of
#     batch 4: ['term', 'of', 'first', 'used']
#     label 4: abuse
#     batch 5: ['of', 'abuse', 'used', 'against']
#     label 5: first
#     batch 6: ['abuse', 'first', 'against', 'early']
#     label 6: used
#     batch 7: ['first', 'used', 'early', 'working']
#     label 7: against
#
# with context_window = 4:
#     batch 0: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label 0: term
#     batch 1: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label 1: of
#     batch 2: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label 2: abuse
#     batch 3: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label 3: first
#     batch 4: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label 4: used
#     batch 5: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label 5: against
#     batch 6: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label 6: early
#     batch 7: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label 7: working

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # This is the alternative to skip_window, however we don't need the skip steps here,
                   # since all words are always included
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Get the sum of the embeddings for the each entry
    embedding_context = tf.reduce_sum(embed, 1)
     
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedding_context,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.617807
# Nearest to the: baer, valiente, herbert, openings, sympathy, teflon, dennis, athenian,
# Nearest to a: cartels, wrongful, corbusier, append, neurotoxicity, scandinavian, gruyter, blizzard,
# Nearest to th: acidic, maximise, barbarians, ronin, secedes, borromini, fringed, logistical,
# Nearest to who: diamonds, symbolised, burgess, cabot, portraying, mathews, chel, shane,
# Nearest to as: die, compatibility, poisonous, tie, tuples, counsellor, point, ras,
# Nearest to from: calcio, mes, plantagenet, senses, preamble, playwrights, archons, reeve,
# Nearest to their: ambients, recitative, boasian, hiller, terraced, stoppage, historian, manhunter,
# Nearest to five: cord, hurrian, marten, petrel, pakistan, bette, encapsulated, enacted,
# Nearest to they: rok, financial, boycotts, tiff, alfonso, reward, wonderland, duties,
# Nearest to eight: professes, lounge, sustenance, amway, remind, retroactive, maimed, stiffness,
# Nearest to about: fielder, igbo, dih, strongly, ryukyu, metamorphosis, history, aotearoa,
# Nearest to most: sportscaster, uart, substitute, juggalo, module, fancher, rees, jahn,
# Nearest to that: nabataean, strenuously, brabant, wy, grammarians, molecular, enhancers, scaled,
# Nearest to so: electrodes, authorship, ccc, extinguish, complicated, fever, horner, thermotropic,
# Nearest to by: dogged, depressing, minaret, clippers, rotten, reconsidered, ffff, eugenie,
# Nearest to united: nonaggression, ceilings, corrections, voltaic, upgraded, theses, szl, sacu,
# Average loss at step 2000: 4.098435
# Average loss at step 4000: 3.565848
# Average loss at step 6000: 3.379944
# Average loss at step 8000: 3.240069
# Average loss at step 10000: 3.177292
# Nearest to the: its, his, their, this, roosevelt, natal, inviscid, communications,
# Nearest to a: neurotoxicity, exit, widen, very, deploying, xxxiv, nebulae, ionian,
# Nearest to th: stella, herring, rennie, barbarians, logistical, lund, fringed, watford,
# Nearest to who: he, which, czarist, sundown, they, also, mung, perseverance,
# Nearest to as: conciliation, when, after, bible, specify, tco, mystical, habitats,
# Nearest to from: into, in, gaon, mes, falun, for, heater, calcio,
# Nearest to their: his, its, her, the, our, recitative, some, manley,
# Nearest to five: six, four, eight, nine, seven, zero, three, two,
# Nearest to they: he, we, there, you, it, who, battlestar, she,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to about: igbo, toppings, replete, dutchman, dijkstra, duodecimal, suddenly, occasions,
# Nearest to most: some, more, many, particularly, winograd, metropolitan, tally, psychoacoustics,
# Nearest to that: which, but, mints, what, it, there, this, wy,
# Nearest to so: authorship, ccc, fever, cones, extinguish, bandleaders, kauffman, arte,
# Nearest to by: eugenie, oi, slew, echoing, lively, prehistory, accumulations, spiritually,
# Nearest to united: socialized, upgraded, billboard, nonaggression, ceilings, corrections, idempotents, faithfully,
# Average loss at step 12000: 3.196708
# Average loss at step 14000: 3.152611
# Average loss at step 16000: 3.177556
# Average loss at step 18000: 3.128927
# Average loss at step 20000: 2.989727
# Nearest to the: a, their, his, its, any, this, binding, slideshow,
# Nearest to a: the, any, another, rabin, xxxiv, exit, sidekick, every,
# Nearest to th: herring, stella, watford, six, barbarians, rennie, eight, ration,
# Nearest to who: which, he, slipknot, she, originally, mung, that, often,
# Nearest to as: dodecahedron, tco, basra, perlite, mystical, torah, willingness, warships,
# Nearest to from: into, mares, through, during, calcio, tolerated, between, pelagius,
# Nearest to their: its, his, her, our, the, your, any, my,
# Nearest to five: six, seven, eight, four, zero, three, nine, two,
# Nearest to they: we, he, there, you, it, she, photography, these,
# Nearest to eight: six, seven, nine, four, five, zero, three, two,
# Nearest to about: strongly, duodecimal, spassky, dih, admittedly, toppings, replete, kj,
# Nearest to most: more, many, particularly, commonwealth, tally, stadtholder, some, distracted,
# Nearest to that: which, what, this, but, however, where, who, gx,
# Nearest to so: ccc, arte, extinguish, usda, kosovo, more, finish, hair,
# Nearest to by: eugenie, reconsidered, when, eccles, accumulations, pictorial, oi, apparatus,
# Nearest to united: upgraded, socialized, billboard, supreme, city, yogurt, console, eastern,
# Average loss at step 22000: 3.075834
# Average loss at step 24000: 3.040849
# Average loss at step 26000: 3.003933
# Average loss at step 28000: 3.028615
# Average loss at step 30000: 3.008893
# Nearest to the: their, a, its, this, our, his, any, kellermann,
# Nearest to a: the, teamsters, clowning, neurotoxicity, widen, baryonic, any, redrawn,
# Nearest to th: herring, rd, ration, twentieth, ghilzai, stella, st, nd,
# Nearest to who: he, which, slipknot, originally, they, she, already, kashmir,
# Nearest to as: njazidja, tco, basra, revulsion, bolshevist, sappho, hydrologic, dodecahedron,
# Nearest to from: into, through, before, calcio, mes, falun, turmoil, during,
# Nearest to their: its, his, her, our, the, your, whose, my,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to they: we, there, he, you, she, it, who, antacids,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to about: over, replete, kj, timur, everest, duodecimal, devry, eng,
# Nearest to most: more, many, some, particularly, kulaks, tally, commonwealth, stadtholder,
# Nearest to that: which, however, what, this, intellectuals, certainly, where, windsor,
# Nearest to so: och, chthonic, extinguish, usda, hallucinogenic, arte, pdf, kauffman,
# Nearest to by: eccles, through, apparatus, without, marge, with, reconsidered, vijayanagara,
# Nearest to united: upgraded, billboard, socialized, supreme, yogurt, console, city, corticosteroids,
# Average loss at step 32000: 2.830741
# Average loss at step 34000: 2.955070
# Average loss at step 36000: 2.946843
# Average loss at step 38000: 2.945410
# Average loss at step 40000: 2.929628
# Nearest to the: their, its, inviscid, a, exe, cowl, each, his,
# Nearest to a: the, another, teamsters, avoidance, janusz, revisionist, capac, neurotoxicity,
# Nearest to th: herring, ration, rd, eight, st, third, nd, fourth,
# Nearest to who: he, often, which, usually, they, originally, slipknot, she,
# Nearest to as: tco, basra, tie, sojourn, dodecahedron, torah, spiritus, theotokos,
# Nearest to from: into, through, before, calcio, after, during, mares, mes,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to they: we, he, you, there, she, it, i, who,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to about: over, chart, suddenly, everest, replete, duodecimal, kj, timur,
# Nearest to most: more, many, some, particularly, less, especially, distracted, commonwealth,
# Nearest to that: which, however, what, intellectuals, monomer, caravans, turkmen, about,
# Nearest to so: och, too, shewa, chthonic, hallucinogenic, before, pdf, doubt,
# Nearest to by: eugenie, marge, reconsidered, through, pictorial, without, apparatus, when,
# Nearest to united: upgraded, billboard, socialized, supreme, border, yogurt, corticosteroids, city,
# Average loss at step 42000: 2.954633
# Average loss at step 44000: 2.957763
# Average loss at step 46000: 2.915783
# Average loss at step 48000: 2.871631
# Average loss at step 50000: 2.842263
# Nearest to the: a, its, their, any, your, his, our, inviscid,
# Nearest to a: the, shamanism, any, another, avoidance, capac, distances, every,
# Nearest to th: herring, rd, third, ration, twentieth, st, diphthongs, nd,
# Nearest to who: he, which, she, originally, ainsworth, also, eventually, usually,
# Nearest to as: tco, sappho, pediatrician, like, before, amer, usemodwiki, hispania,
# Nearest to from: into, during, through, across, in, mes, within, under,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to they: we, there, you, he, she, it, antacids, who,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to about: over, chart, altogether, suddenly, cautious, marcuse, everest, storm,
# Nearest to most: more, many, particularly, some, less, especially, several, all,
# Nearest to that: which, what, however, this, where, globalisation, it, wy,
# Nearest to so: och, too, sometimes, shewa, powders, before, ump, dogg,
# Nearest to by: through, without, eccles, when, chronicled, eugenie, licht, ny,
# Nearest to united: upgraded, billboard, socialized, border, supreme, yogurt, confederate, roman,
# Average loss at step 52000: 2.885760
# Average loss at step 54000: 2.859104
# Average loss at step 56000: 2.859340
# Average loss at step 58000: 2.751873
# Average loss at step 60000: 2.833286
# Nearest to the: its, their, each, this, any, his, our, inviscid,
# Nearest to a: another, shamanism, the, clowning, avoidance, lahr, teamsters, any,
# Nearest to th: herring, rd, ration, twentieth, third, nd, fourth, st,
# Nearest to who: which, she, he, often, also, already, usually, slipknot,
# Nearest to as: basra, sappho, tco, zeppelin, njazidja, shankar, interrogators, pediatrician,
# Nearest to from: into, in, during, through, pelagius, cruises, within, under,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to five: seven, four, six, eight, nine, zero, three, two,
# Nearest to they: we, you, he, there, she, it, arma, etc,
# Nearest to eight: nine, seven, six, five, four, three, two, zero,
# Nearest to about: over, father, wittelsbach, chart, dendritic, regarding, seduce, everest,
# Nearest to most: more, particularly, especially, many, some, because, purse, less,
# Nearest to that: which, what, however, where, lorre, caravans, crooks, sorbian,
# Nearest to so: sometimes, too, och, chthonic, casinos, kaposi, eventually, entrepreneurs,
# Nearest to by: pictorial, slew, eugenie, eccles, from, chronicled, anoa, backpacker,
# Nearest to united: upgraded, border, billboard, yogurt, socialized, roman, confederate, continuum,
# Average loss at step 62000: 2.834281
# Average loss at step 64000: 2.769828
# Average loss at step 66000: 2.760701
# Average loss at step 68000: 2.716072
# Average loss at step 70000: 2.779387
# Nearest to the: its, their, his, a, any, your, each, our,
# Nearest to a: the, another, any, every, avoidance, shamanism, capac, teamsters,
# Nearest to th: herring, third, twentieth, rd, fourth, ration, nd, six,
# Nearest to who: he, which, she, already, briefly, slipknot, dk, also,
# Nearest to as: when, predicting, tco, basra, disambiguation, jdf, tie, zeppelin,
# Nearest to from: mes, through, into, calcio, after, before, during, under,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to they: we, you, he, she, there, these, dunsany, it,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to about: over, wittelsbach, amoeboid, marxists, seduce, ashore, counseled, suddenly,
# Nearest to most: more, particularly, many, especially, some, less, commonwealth, purse,
# Nearest to that: which, what, however, where, but, lorre, certainly, herd,
# Nearest to so: too, sometimes, och, something, chthonic, later, before, dogg,
# Nearest to by: without, through, eccles, eugenie, when, while, reconsidered, boleyn,
# Nearest to united: upgraded, confederate, billboard, border, ball, yogurt, socialized, european,
# Average loss at step 72000: 2.798745
# Average loss at step 74000: 2.649671
# Average loss at step 76000: 2.809220
# Average loss at step 78000: 2.823962
# Average loss at step 80000: 2.780653
# Nearest to the: their, its, our, a, inviscid, ien, any, sephardim,
# Nearest to a: another, the, baryonic, shamanism, teamsters, avoidance, janusz, every,
# Nearest to th: twentieth, rd, herring, nd, st, third, fourth, six,
# Nearest to who: which, he, already, she, frankly, busan, intact, briefly,
# Nearest to as: mkultra, when, like, akkadian, leitch, tco, idempotent, njazidja,
# Nearest to from: into, through, mes, in, across, during, within, zia,
# Nearest to their: its, his, her, our, your, the, whose, my,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to they: we, you, he, there, she, i, it, these,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to about: over, regarding, dendritic, wittelsbach, effluents, chart, seduce, amoeboid,
# Nearest to most: particularly, more, many, especially, some, less, because, several,
# Nearest to that: which, what, however, this, constitutive, gebhard, where, rockefeller,
# Nearest to so: too, endian, once, sometimes, chthonic, concluded, how, pivots,
# Nearest to by: when, using, without, eugenie, during, despite, through, pictorial,
# Nearest to united: confederate, border, upgraded, european, upcoming, billboard, yogurt, socialized,
# Average loss at step 82000: 2.669644
# Average loss at step 84000: 2.772216
# Average loss at step 86000: 2.732768
# Average loss at step 88000: 2.752165
# Average loss at step 90000: 2.739579
# Nearest to the: its, his, their, our, any, this, keeshond, exe,
# Nearest to a: another, shamanism, the, spooky, avoidance, oghuz, any, teamsters,
# Nearest to th: rd, herring, fourth, twentieth, nd, third, sixth, five,
# Nearest to who: which, he, slipknot, already, never, they, frankly, intact,
# Nearest to as: jdf, tco, including, nashwaak, after, poz, sappho, mkultra,
# Nearest to from: into, through, mes, including, during, in, across, under,
# Nearest to their: its, his, her, our, your, whose, my, the,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to they: we, you, he, there, she, i, it, antacids,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to about: over, regarding, around, dendritic, chart, seduce, everest, wittelsbach,
# Nearest to most: more, particularly, some, less, especially, many, several, because,
# Nearest to that: which, what, however, currently, how, certainly, furthermore, crooks,
# Nearest to so: too, sometimes, chthonic, endian, concluded, boardwalk, rothbard, once,
# Nearest to by: through, pictorial, including, toward, eugenie, marge, using, impatient,
# Nearest to united: upgraded, border, confederate, upcoming, yogurt, usa, billboard, socialized,
# Average loss at step 92000: 2.680458
# Average loss at step 94000: 2.729633
# Average loss at step 96000: 2.699987
# Average loss at step 98000: 2.366904
# Average loss at step 100000: 2.397147
# Nearest to the: his, their, its, our, this, her, a, cowl,
# Nearest to a: another, shamanism, the, spooky, janusz, baryonic, flavia, teamsters,
# Nearest to th: nd, herring, rd, twentieth, fourth, third, ce, sixth,
# Nearest to who: he, she, often, already, which, never, actually, still,
# Nearest to as: shankar, gerhard, tie, njazidja, pediatrician, because, tco, basra,
# Nearest to from: through, mes, during, into, across, under, abolitionists, after,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to five: four, seven, six, eight, three, nine, two, zero,
# Nearest to they: we, he, you, there, she, it, i, these,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to about: over, regarding, seduce, wittelsbach, everest, around, chart, unmarried,
# Nearest to most: more, less, especially, particularly, many, some, extremely, increasingly,
# Nearest to that: which, however, what, furthermore, how, whom, estimators, raf,
# Nearest to so: too, sometimes, once, then, endian, boardwalk, indeed, thus,
# Nearest to by: licht, through, without, pictorial, towards, when, sanger, duodenum,
# Nearest to united: confederate, border, upgraded, uk, usa, billboard, upcoming, baltic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
