# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.808108
# Nearest to but: synonym, disregarded, lyricists, ime, bestiary, ephemerides, boulder, aries,
# Nearest to years: bayreuth, centralised, comical, tydings, gerry, hauk, fh, avon,
# Nearest to if: eritreans, encyclopedias, fledging, paddock, masquerade, ditches, averages, araki,
# Nearest to system: ruled, scalar, ange, homeowners, ho, albertine, concretely, garcia,
# Nearest to this: cali, compassion, airway, allen, autocephalous, tumbling, athos, silberman,
# Nearest to state: hells, lysander, feline, earls, veitch, kaos, communicative, catalogues,
# Nearest to are: disposed, slight, innovations, fujiko, herat, stouffer, boyle, tequila,
# Nearest to their: monopolize, terminated, aberdeenshire, northeasterly, gbase, csc, oppidum, bahama,
# Nearest to his: participate, envoys, whist, comics, embryo, samarium, predicate, novello,
# Nearest to american: repression, nyasa, nests, bongo, nonnegative, specialisation, praising, mental,
# Nearest to most: devout, telescope, acth, technocrats, regional, boc, devious, generalisations,
# Nearest to b: bowler, cares, coatings, devon, adjustable, slalom, wish, functioning,
# Nearest to some: placed, norden, peaches, holley, backstreet, creditors, downloadable, pythagoras,
# Nearest to which: swanson, limbs, vim, nasi, trusts, private, stamens, newsted,
# Nearest to with: fetch, color, plentiful, internally, chancellorsville, nav, clearly, maryam,
# Nearest to four: luke, heimdall, notoriety, ligamentum, cleaners, sweyn, rejected, midi,
# Average loss at step 2000: 4.371850
# Average loss at step 4000: 3.863505
# Average loss at step 6000: 3.792698
# Average loss at step 8000: 3.690868
# Average loss at step 10000: 3.610749
# Nearest to but: were, are, which, carpetbaggers, bestiary, lyricists, almost, rivest,
# Nearest to years: centralised, rulership, gale, fh, broadband, arundel, slingshot, possibly,
# Nearest to if: eritreans, fledging, advice, eyre, encyclopedias, do, averages, jupiter,
# Nearest to system: ruled, homeowners, scalar, zhdanov, rubin, nicht, concretely, analogue,
# Nearest to this: it, any, which, the, that, rolled, slash, constitutions,
# Nearest to state: feline, dweller, despot, kara, wakes, parts, lysander, hells,
# Nearest to are: were, is, have, but, include, violation, goya, stanton,
# Nearest to their: his, its, heir, bribes, this, northeasterly, ccd, any,
# Nearest to his: their, the, its, her, s, a, mystique, tico,
# Nearest to american: choral, specialisation, b, menelik, moderne, desperate, mental, mosquitoes,
# Nearest to most: acth, devout, boc, riders, devious, telescope, lengthening, pineapple,
# Nearest to b: d, american, havas, cares, rivera, rehearsals, and, nicht,
# Nearest to some: many, signatories, peaches, several, other, tidal, adventists, guitarists,
# Nearest to which: that, this, stamens, but, who, it, also, digamma,
# Nearest to with: in, for, promptly, pickles, internally, or, of, from,
# Nearest to four: six, seven, three, eight, five, two, zero, nine,
# Average loss at step 12000: 3.607370
# Average loss at step 14000: 3.574820
# Average loss at step 16000: 3.411629
# Average loss at step 18000: 3.454868
# Average loss at step 20000: 3.548591
# Nearest to but: however, is, methylene, cloning, which, did, and, if,
# Nearest to years: centralised, rulership, gale, atzeret, callimico, gerry, cereals, irbms,
# Nearest to if: fledging, eritreans, however, but, happened, might, advice, do,
# Nearest to system: homeowners, analogue, scalar, ruled, rubin, disaster, zhdanov, nicht,
# Nearest to this: it, which, the, any, that, he, a, racing,
# Nearest to state: dweller, kara, feline, despot, btr, mash, wakes, philly,
# Nearest to are: were, is, have, responded, sobriety, ubu, was, goya,
# Nearest to their: its, his, the, any, her, some, them, heir,
# Nearest to his: their, her, its, the, tico, participate, some, predicate,
# Nearest to american: specialisation, british, mental, choral, vest, peta, french, mosquitoes,
# Nearest to most: more, riders, acth, some, boc, many, pineapple, devious,
# Nearest to b: d, sterling, beak, immanuel, tarski, orf, havas, ties,
# Nearest to some: many, several, these, other, their, most, all, its,
# Nearest to which: that, this, who, also, it, but, dependant, anhui,
# Nearest to with: in, by, for, clearly, promptly, or, from, pickles,
# Nearest to four: six, seven, three, eight, five, two, nine, zero,
# Average loss at step 22000: 3.505341
# Average loss at step 24000: 3.495794
# Average loss at step 26000: 3.484218
# Average loss at step 28000: 3.482648
# Average loss at step 30000: 3.502245
# Nearest to but: however, and, although, which, did, cloning, while, that,
# Nearest to years: rulership, days, centralised, gerry, cereals, irbms, callimico, retinal,
# Nearest to if: however, though, fledging, when, eritreans, hovering, do, eccles,
# Nearest to system: analogue, difference, here, scalar, willi, kaleidoscope, parisian, fleas,
# Nearest to this: which, it, there, not, that, any, the, plaza,
# Nearest to state: kara, philly, dweller, feline, churches, mutinied, corso, btr,
# Nearest to are: were, have, is, include, other, ubu, although, these,
# Nearest to their: its, his, the, her, our, some, these, any,
# Nearest to his: their, her, its, the, s, this, blackhawks, participate,
# Nearest to american: italian, vest, british, french, english, aryabhata, seifert, german,
# Nearest to most: more, some, many, ilm, riders, acth, devious, boc,
# Nearest to b: d, sterling, rehearsals, medici, farthest, tia, orf, keynesianism,
# Nearest to some: many, several, these, all, most, their, any, the,
# Nearest to which: this, that, but, who, also, it, these, digamma,
# Nearest to with: between, plentiful, promptly, when, codasyl, in, against, banisteriopsis,
# Nearest to four: five, three, six, eight, seven, two, nine, zero,
# Average loss at step 32000: 3.503521
# Average loss at step 34000: 3.493798
# Average loss at step 36000: 3.455298
# Average loss at step 38000: 3.301751
# Average loss at step 40000: 3.428310
# Nearest to but: however, and, which, although, it, where, shall, could,
# Nearest to years: days, months, rulership, decades, centuries, times, cereals, callimico,
# Nearest to if: is, when, though, however, fledging, where, duryodhana, eyre,
# Nearest to system: systems, analogue, fleas, willi, scalar, difference, kaleidoscope, parisian,
# Nearest to this: which, it, the, that, any, subregion, another, hotly,
# Nearest to state: kara, mash, establishment, expandable, philly, despot, churches, government,
# Nearest to are: were, is, have, include, be, these, including, hating,
# Nearest to their: its, his, her, the, our, these, some, any,
# Nearest to his: their, her, its, the, s, your, my, blackhawks,
# Nearest to american: italian, french, english, british, vest, german, sakharov, russian,
# Nearest to most: more, some, less, boc, riders, monazite, ilm, midrashic,
# Nearest to b: d, sterling, UNK, indexing, derek, c, tarski, f,
# Nearest to some: many, these, several, any, certain, various, detective, their,
# Nearest to which: that, this, also, it, who, but, there, anhui,
# Nearest to with: when, between, galilean, assamese, promptly, without, in, codasyl,
# Nearest to four: six, seven, five, three, eight, two, nine, one,
# Average loss at step 42000: 3.440877
# Average loss at step 44000: 3.457900
# Average loss at step 46000: 3.449807
# Average loss at step 48000: 3.356566
# Average loss at step 50000: 3.383808
# Nearest to but: however, although, and, though, which, while, when, where,
# Nearest to years: days, months, decades, rulership, times, minutes, centuries, people,
# Nearest to if: when, though, where, since, superseding, before, duryodhana, although,
# Nearest to system: systems, analogue, willi, parisian, fleas, scalar, sorbonne, eastward,
# Nearest to this: which, it, the, that, he, animator, tms, mint,
# Nearest to state: establishment, mash, kara, corso, despot, philly, harvard, walled,
# Nearest to are: were, is, have, although, include, these, be, seabirds,
# Nearest to their: its, his, her, the, some, our, these, any,
# Nearest to his: her, their, its, my, your, the, our, kosrae,
# Nearest to american: italian, african, vest, english, japanese, french, german, sakharov,
# Nearest to most: more, less, some, excelling, midrashic, monazite, riders, ilm,
# Nearest to b: d, sterling, gila, c, r, derek, aud, logicians,
# Nearest to some: many, several, these, various, any, both, especially, most,
# Nearest to which: this, that, also, but, who, often, what, where,
# Nearest to with: between, clearly, mercer, in, spatially, dylan, sanskrit, by,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Average loss at step 52000: 3.436702
# Average loss at step 54000: 3.432550
# Average loss at step 56000: 3.442932
# Average loss at step 58000: 3.400957
# Average loss at step 60000: 3.393671
# Nearest to but: however, and, although, which, see, when, than, ssp,
# Nearest to years: days, decades, months, centuries, minutes, times, rulership, year,
# Nearest to if: when, where, though, since, before, however, duryodhana, because,
# Nearest to system: systems, analogue, difference, parisian, belloc, network, willi, regimes,
# Nearest to this: it, which, that, there, what, the, some, fief,
# Nearest to state: establishment, states, mash, corso, despot, base, feline, philly,
# Nearest to are: were, is, have, include, although, emanating, including, these,
# Nearest to their: its, his, her, the, our, these, some, defuse,
# Nearest to his: her, their, its, my, your, blackhawks, our, hobby,
# Nearest to american: italian, african, vest, british, german, isin, english, creams,
# Nearest to most: more, many, some, excelling, less, use, midrashic, monazite,
# Nearest to b: d, c, r, gila, k, f, sterling, logicians,
# Nearest to some: many, several, these, any, various, most, their, negotiator,
# Nearest to which: that, this, these, but, it, there, who, what,
# Nearest to with: between, promptly, when, stenella, plentiful, postpone, spatially, constipation,
# Nearest to four: six, five, eight, three, seven, two, nine, zero,
# Average loss at step 62000: 3.239630
# Average loss at step 64000: 3.253582
# Average loss at step 66000: 3.403486
# Average loss at step 68000: 3.398356
# Average loss at step 70000: 3.359812
# Nearest to but: however, although, which, that, and, while, nor, when,
# Nearest to years: days, decades, months, minutes, times, year, centuries, rulership,
# Nearest to if: when, though, where, before, since, however, after, could,
# Nearest to system: systems, analogue, fleas, network, parisian, regimes, belloc, program,
# Nearest to this: which, it, that, the, what, another, there, mint,
# Nearest to state: states, government, philly, mash, heineken, expandable, refering, corso,
# Nearest to are: were, although, is, have, including, include, these, while,
# Nearest to their: its, his, her, the, our, some, these, alcohol,
# Nearest to his: her, their, its, my, your, our, blackhawks, the,
# Nearest to american: vest, british, italian, african, creams, haitians, english, german,
# Nearest to most: more, less, many, some, excelling, use, midrashic, especially,
# Nearest to b: d, f, k, c, r, h, farrar, sterling,
# Nearest to some: many, several, these, any, their, most, various, all,
# Nearest to which: that, this, also, what, but, usually, who, these,
# Nearest to with: between, while, plentiful, when, savants, ccc, by, assamese,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Average loss at step 72000: 3.379116
# Average loss at step 74000: 3.351464
# Average loss at step 76000: 3.313571
# Average loss at step 78000: 3.352246
# Average loss at step 80000: 3.375784
# Nearest to but: however, although, and, which, while, see, blackjack, though,
# Nearest to years: days, months, decades, minutes, times, year, centuries, hours,
# Nearest to if: when, though, before, since, where, superseding, after, unless,
# Nearest to system: systems, analogue, program, network, fleas, archimedes, regimes, difference,
# Nearest to this: which, it, there, the, what, that, some, repressions,
# Nearest to state: states, government, establishment, mash, despot, corso, daisies, city,
# Nearest to are: were, include, have, is, although, exist, these, be,
# Nearest to their: its, his, her, our, your, the, my, these,
# Nearest to his: her, their, its, my, your, our, blackhawks, the,
# Nearest to american: british, italian, vest, isin, creams, german, aryabhata, english,
# Nearest to most: some, more, many, less, excelling, use, midrashic, especially,
# Nearest to b: d, c, farrar, h, r, k, sterling, f,
# Nearest to some: many, several, most, these, various, any, certain, especially,
# Nearest to which: this, that, usually, also, often, but, these, where,
# Nearest to with: between, among, when, promptly, postpone, on, forma, clearly,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Average loss at step 82000: 3.406727
# Average loss at step 84000: 3.413242
# Average loss at step 86000: 3.389002
# Average loss at step 88000: 3.352628
# Average loss at step 90000: 3.366969
# Nearest to but: however, and, although, though, while, which, until, or,
# Nearest to years: days, months, decades, minutes, year, centuries, hours, times,
# Nearest to if: when, though, since, where, before, superseding, woensel, unless,
# Nearest to system: systems, analogue, program, network, iblis, regimes, principle, primaries,
# Nearest to this: which, it, the, some, another, itself, similar, salutation,
# Nearest to state: government, city, despot, mash, states, turpentine, establishment, mutinied,
# Nearest to are: were, is, include, have, these, exist, contain, although,
# Nearest to their: its, his, her, our, the, your, whose, my,
# Nearest to his: her, their, its, my, your, our, the, blackhawks,
# Nearest to american: british, italian, vest, isin, german, african, french, aryabhata,
# Nearest to most: more, many, less, some, excelling, midrashic, especially, use,
# Nearest to b: c, d, r, farrar, k, nipple, ff, h,
# Nearest to some: many, several, these, certain, all, various, most, especially,
# Nearest to which: this, that, usually, what, also, there, but, these,
# Nearest to with: between, by, in, into, galilean, inevitability, against, rusty,
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Average loss at step 92000: 3.397897
# Average loss at step 94000: 3.251823
# Average loss at step 96000: 3.356262
# Average loss at step 98000: 3.246787
# Average loss at step 100000: 3.359672
# Nearest to but: however, although, and, which, while, though, that, neri,
# Nearest to years: days, decades, months, minutes, year, times, hours, centuries,
# Nearest to if: when, where, though, before, since, superseding, unless, although,
# Nearest to system: systems, archimedes, analogue, program, network, fleas, artisans, process,
# Nearest to this: which, it, another, some, itself, salutation, what, the,
# Nearest to state: city, government, states, college, harvard, turpentine, despot, mash,
# Nearest to are: were, have, include, these, is, exist, be, including,
# Nearest to their: its, his, her, our, your, the, these, whose,
# Nearest to his: her, their, your, its, my, our, the, s,
# Nearest to american: british, canadian, italian, vest, isin, haitians, australian, creams,
# Nearest to most: more, less, especially, excelling, midrashic, particularly, use, many,
# Nearest to b: d, c, farthest, sterling, bogged, who, orf, symbolically,
# Nearest to some: many, several, these, any, certain, various, numerous, especially,
# Nearest to which: that, this, what, usually, but, these, also, typically,
# Nearest to with: between, against, in, when, into, animist, benno, stenella,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ context_window target context_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[context_window]
        target = context_window
        k = 0
        for j in range(span):
            if j != context_window:
                batch[i][k] = buffer[j]
                k = k + 1
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for idx in range(8):
        print('    batch %d: %s' % (idx, [reverse_dictionary[bi] for bi in batch[idx]]))
        print('    label %d: %s' % (idx, reverse_dictionary[labels[idx, 0]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with context_window = 2:
#     batch 0: ['anarchism', 'originated', 'a', 'term']
#     label 0: as
#     batch 1: ['originated', 'as', 'term', 'of']
#     label 1: a
#     batch 2: ['as', 'a', 'of', 'abuse']
#     label 2: term
#     batch 3: ['a', 'term', 'abuse', 'first']
#     label 3: of
#     batch 4: ['term', 'of', 'first', 'used']
#     label 4: abuse
#     batch 5: ['of', 'abuse', 'used', 'against']
#     label 5: first
#     batch 6: ['abuse', 'first', 'against', 'early']
#     label 6: used
#     batch 7: ['first', 'used', 'early', 'working']
#     label 7: against
#
# with context_window = 4:
#     batch 0: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label 0: term
#     batch 1: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label 1: of
#     batch 2: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label 2: abuse
#     batch 3: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label 3: first
#     batch 4: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label 4: used
#     batch 5: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label 5: against
#     batch 6: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label 6: early
#     batch 7: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label 7: working

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # This is the alternative to skip_window, however we don't need the skip steps here,
                   # since all words are always included
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Get the sum of the embeddings for the each entry
    embedding_context = tf.reduce_sum(embed, 1)
     
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedding_context,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.855798
# Nearest to had: autocad, moncton, spool, huguenot, rhead, tenures, provability, nitrates,
# Nearest to no: bryson, arbitrarily, espagnole, reopening, premeditated, socio, skirts, unintentionally,
# Nearest to years: osama, aml, cossacks, lineker, synaptic, tremont, compass, bahamas,
# Nearest to he: verona, immunotherapy, celebrating, bouchard, deconstructionist, abdicate, belonging, prophase,
# Nearest to if: screenshots, purim, trout, balas, perens, false, parentage, affront,
# Nearest to a: bartlett, tallest, go, emeralds, musketeers, irma, hannibal, streetcars,
# Nearest to united: inspector, toil, stencils, rainforest, gaelic, socialized, ivory, twitch,
# Nearest to state: gcl, malignancies, landed, submission, address, intervene, ambivalent, anthems,
# Nearest to eight: forrestal, exponentials, batcave, inhaling, deterred, axp, cymbal, alluding,
# Nearest to they: reintroduction, adds, denominated, tyne, soma, atman, deduction, transliteration,
# Nearest to often: essential, shelter, specifying, devoiced, distinction, jaian, abijah, dogbert,
# Nearest to these: silverstein, bachelors, barefoot, gloria, drives, nebulous, sufism, euphoria,
# Nearest to some: trygve, graphically, caddy, utamaro, elitism, luzon, ncipe, inhabit,
# Nearest to his: revenue, efficiencies, curved, choked, uniformed, lakeshore, bet, unwavering,
# Nearest to american: visceral, prolog, firewall, belatedly, depleted, llewellyn, unmibh, ushering,
# Nearest to use: elemental, yazoo, dill, neoplatonism, torres, reims, lowry, vecchio,
# Average loss at step 2000: 4.096982
# Average loss at step 4000: 3.560684
# Average loss at step 6000: 3.388370
# Average loss at step 8000: 3.244579
# Average loss at step 10000: 3.179094
# Nearest to had: has, have, was, were, harum, having, chose, angers,
# Nearest to no: bryson, mcfarland, humans, any, airtime, zvi, shahanshah, moretti,
# Nearest to years: undisclosed, competes, cossacks, springboard, toru, perception, snub, lagged,
# Nearest to he: it, she, they, who, there, excelling, ims, loader,
# Nearest to if: could, eiffel, when, groundbreaking, defaults, screenshots, regularity, involves,
# Nearest to a: very, the, ballista, plaques, any, ribbon, bsd, hawkins,
# Nearest to united: senators, czar, stencils, mim, socialized, epiphanes, pepe, firebird,
# Nearest to state: cerebrum, ying, europium, unlucky, luening, opera, supplementing, exceeding,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to they: he, we, there, adds, it, you, who, she,
# Nearest to often: essential, devoiced, sometimes, oahu, obstruct, angina, commonly, gaud,
# Nearest to these: some, many, genera, intuitively, ayres, silverstein, several, other,
# Nearest to some: many, several, other, these, most, inhabit, subtly, this,
# Nearest to his: their, her, its, the, interstate, whose, strived, my,
# Nearest to american: wichita, unmibh, impediments, shredded, obsidian, mock, dusseldorf, firewall,
# Nearest to use: adar, last, sadism, kapellmeister, grit, reputation, teatro, sings,
# Average loss at step 12000: 3.207039
# Average loss at step 14000: 3.150682
# Average loss at step 16000: 3.174264
# Average loss at step 18000: 3.124804
# Average loss at step 20000: 2.990384
# Nearest to had: has, have, was, were, having, fyrom, doped, crandall,
# Nearest to no: any, a, aur, macmullen, eared, bryson, moderating, sarcophagi,
# Nearest to years: days, months, times, undisclosed, robeson, competes, year, snub,
# Nearest to he: it, she, they, who, there, i, eventually, loader,
# Nearest to if: when, bjorn, though, could, where, for, since, screenshots,
# Nearest to a: the, any, no, deo, another, orton, mcconnell, every,
# Nearest to united: mim, senators, epiphanes, czar, stencils, tines, blizzards, alkmaar,
# Nearest to state: government, ying, states, europium, cerebrum, unlucky, oriole, barbarians,
# Nearest to eight: six, seven, nine, four, five, zero, three, two,
# Nearest to they: we, there, he, you, she, it, adds, these,
# Nearest to often: usually, commonly, sometimes, still, also, not, obstruct, generally,
# Nearest to these: some, many, several, such, they, genera, ingolstadt, there,
# Nearest to some: many, these, several, various, most, those, both, berliner,
# Nearest to his: their, her, its, my, the, whose, s, strived,
# Nearest to american: australian, unmibh, impediments, english, satisfactorily, kazan, dishonesty, andhra,
# Nearest to use: adar, last, teatro, sings, represent, disappointing, sadism, circle,
# Average loss at step 22000: 3.073931
# Average loss at step 24000: 3.038466
# Average loss at step 26000: 3.003022
# Average loss at step 28000: 3.032855
# Average loss at step 30000: 3.009720
# Nearest to had: has, have, was, were, having, crandall, successfully, fyrom,
# Nearest to no: any, little, bryson, argon, urgent, trumpets, sobriety, eared,
# Nearest to years: days, months, times, year, undisclosed, robeson, snub, columbians,
# Nearest to he: she, it, they, who, there, originally, bosco, eventually,
# Nearest to if: when, where, though, since, rodrigues, before, could, screenshots,
# Nearest to a: another, the, madison, drachmae, underdog, undated, kerk, fontainebleau,
# Nearest to united: mim, epiphanes, czar, same, ceasing, stencils, alkmaar, senators,
# Nearest to state: government, states, sprint, oriole, galicia, drinker, lahore, supplementing,
# Nearest to eight: nine, four, seven, six, five, zero, three, two,
# Nearest to they: there, we, you, he, she, it, nowadays, these,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, also, now,
# Nearest to these: some, many, several, such, those, genera, various, there,
# Nearest to some: many, several, these, various, any, most, certain, those,
# Nearest to his: her, their, my, its, whose, your, jumpers, interstate,
# Nearest to american: australian, indian, dishonesty, unmibh, english, kazan, andhra, impediments,
# Nearest to use: adar, sadism, fear, last, sings, most, alkyne, lay,
# Average loss at step 32000: 2.829909
# Average loss at step 34000: 2.952373
# Average loss at step 36000: 2.945489
# Average loss at step 38000: 2.943954
# Average loss at step 40000: 2.932434
# Nearest to had: has, have, having, were, was, crandall, successfully, ever,
# Nearest to no: little, any, parapsychology, edomites, noa, rhetorician, bryson, trumpets,
# Nearest to years: days, months, times, year, decades, weeks, centuries, hours,
# Nearest to he: she, it, there, they, who, executing, klaus, we,
# Nearest to if: when, rodrigues, before, since, though, where, reflects, cannot,
# Nearest to a: another, the, emanation, drachmae, veritas, compliment, gv, milos,
# Nearest to united: mim, same, alkmaar, epiphanes, pepe, czar, ceasing, tines,
# Nearest to state: government, sprint, donau, ownership, city, peppers, nk, states,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to they: we, there, you, he, she, it, i, these,
# Nearest to often: sometimes, usually, commonly, generally, also, still, frequently, typically,
# Nearest to these: such, those, several, many, both, some, various, their,
# Nearest to some: many, several, various, both, any, those, most, certain,
# Nearest to his: her, their, my, your, its, our, the, whose,
# Nearest to american: african, indian, australian, andhra, americans, canadian, psyche, khmer,
# Nearest to use: adar, fear, warn, chiba, threaten, sings, sadism, alkyne,
# Average loss at step 42000: 2.954606
# Average loss at step 44000: 2.961266
# Average loss at step 46000: 2.911088
# Average loss at step 48000: 2.870665
# Average loss at step 50000: 2.843748
# Nearest to had: has, have, was, having, were, did, chose, began,
# Nearest to no: any, little, noa, parapsychology, probable, mandating, salinger, edomites,
# Nearest to years: days, months, times, decades, year, hours, weeks, centuries,
# Nearest to he: she, it, they, there, who, we, subsequently, girlfriends,
# Nearest to if: when, though, where, while, before, since, rodrigues, photius,
# Nearest to a: the, any, another, veritas, deo, jumps, gv, compliment,
# Nearest to united: alkmaar, mim, epiphanes, athenian, czar, late, amazingly, pepe,
# Nearest to state: government, city, sprint, states, number, ownership, cerebrum, donau,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to they: we, there, you, he, she, it, these, adds,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, now, still,
# Nearest to these: several, many, some, those, various, numerous, both, their,
# Nearest to some: many, several, any, these, various, certain, most, those,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to american: british, andhra, canadian, impediments, unmibh, reassured, italian, australian,
# Nearest to use: adar, fear, reminds, threaten, need, eln, sings, shoot,
# Average loss at step 52000: 2.893661
# Average loss at step 54000: 2.866520
# Average loss at step 56000: 2.855412
# Average loss at step 58000: 2.755328
# Average loss at step 60000: 2.829172
# Nearest to had: has, have, was, having, were, ever, never, since,
# Nearest to no: little, any, silicone, mandating, another, edomites, mechanised, probable,
# Nearest to years: months, days, times, decades, year, weeks, hours, minutes,
# Nearest to he: she, it, they, there, i, who, girlfriends, constantine,
# Nearest to if: when, though, since, while, before, where, although, because,
# Nearest to a: another, the, deo, any, emanation, compliment, drachmae, veritas,
# Nearest to united: mim, epiphanes, athenian, alkmaar, ceasing, czar, cursor, confederate,
# Nearest to state: sprint, number, states, government, owning, city, oriole, peppers,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to they: we, there, you, he, she, it, i, these,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, also,
# Nearest to these: several, those, many, various, some, numerous, such, both,
# Nearest to some: many, several, any, these, those, various, most, numerous,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to american: canadian, british, italian, australian, anime, andhra, austrian, african,
# Nearest to use: represent, threaten, unscientific, need, adar, result, chiba, usage,
# Average loss at step 62000: 2.836738
# Average loss at step 64000: 2.772960
# Average loss at step 66000: 2.761287
# Average loss at step 68000: 2.715748
# Average loss at step 70000: 2.784337
# Nearest to had: has, have, was, having, were, harum, successfully, eventually,
# Nearest to no: little, any, psychoactive, corpora, mandating, kaunda, recollection, viral,
# Nearest to years: days, months, decades, times, year, weeks, minutes, hours,
# Nearest to he: she, it, they, there, who, eventually, quickly, originally,
# Nearest to if: when, though, where, since, before, cannot, because, after,
# Nearest to a: another, the, veritas, any, hyman, milos, every, emanation,
# Nearest to united: mim, confederate, alkmaar, ceasing, cursor, epiphanes, czar, athenian,
# Nearest to state: government, states, sprint, princeton, city, shortness, lasker, number,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to they: we, you, he, she, there, it, these, canby,
# Nearest to often: sometimes, usually, commonly, typically, frequently, generally, now, still,
# Nearest to these: those, several, some, numerous, many, various, both, such,
# Nearest to some: many, several, these, various, numerous, any, those, certain,
# Nearest to his: her, their, my, its, whose, our, your, the,
# Nearest to american: australian, canadian, italian, irish, british, african, austrian, english,
# Nearest to use: list, sense, cause, usage, adar, signers, need, threaten,
# Average loss at step 72000: 2.802115
# Average loss at step 74000: 2.651635
# Average loss at step 76000: 2.801405
# Average loss at step 78000: 2.824657
# Average loss at step 80000: 2.777364
# Nearest to had: has, have, having, was, were, successfully, ever, ve,
# Nearest to no: any, little, psychoactive, rhetorician, viral, sobriety, gil, grammatik,
# Nearest to years: months, days, decades, times, year, minutes, weeks, hours,
# Nearest to he: she, it, they, there, who, we, girlfriends, bosco,
# Nearest to if: when, though, where, cannot, before, since, direction, joys,
# Nearest to a: another, the, veritas, kerk, gv, emanation, baskets, milos,
# Nearest to united: mim, confederate, athenian, cursor, czar, ceasing, epiphanes, nation,
# Nearest to state: states, government, sprint, congress, ownership, galilee, kingdom, princeton,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to they: we, you, he, there, she, i, it, these,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, now, also,
# Nearest to these: several, those, some, many, examples, such, both, ingolstadt,
# Nearest to some: many, several, various, those, certain, both, any, these,
# Nearest to his: her, their, my, your, its, our, whose, strived,
# Nearest to american: australian, canadian, italian, british, irish, african, indian, german,
# Nearest to use: sense, usage, adar, represent, importance, need, form, explosives,
# Average loss at step 82000: 2.664805
# Average loss at step 84000: 2.776446
# Average loss at step 86000: 2.740009
# Average loss at step 88000: 2.758756
# Average loss at step 90000: 2.733305
# Nearest to had: has, have, was, were, having, ever, ve, harum,
# Nearest to no: any, little, rhetorician, silicone, grammatik, psychoactive, honeybee, mandating,
# Nearest to years: days, months, decades, year, weeks, minutes, hours, times,
# Nearest to he: she, it, they, there, bosco, originally, we, who,
# Nearest to if: when, though, before, where, cannot, since, did, untitled,
# Nearest to a: another, veritas, the, emanation, milos, undated, compliment, every,
# Nearest to united: mim, athenian, confederate, cursor, romans, ceasing, vineyard, usc,
# Nearest to state: states, sprint, government, donau, city, princeton, constitution, congress,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to often: sometimes, usually, typically, commonly, frequently, generally, now, also,
# Nearest to these: those, such, several, examples, many, they, some, various,
# Nearest to some: many, several, various, certain, numerous, both, most, any,
# Nearest to his: her, their, your, my, our, its, whose, the,
# Nearest to american: australian, canadian, british, italian, indian, african, reassured, americans,
# Nearest to use: sense, represent, form, usage, need, fear, importance, cause,
# Average loss at step 92000: 2.683176
# Average loss at step 94000: 2.724341
# Average loss at step 96000: 2.700547
# Average loss at step 98000: 2.369241
# Average loss at step 100000: 2.406790
# Nearest to had: has, have, having, was, were, ve, wanted, ever,
# Nearest to no: any, little, rhetorician, gil, psychoactive, argon, delusions, mandating,
# Nearest to years: days, months, decades, year, weeks, hours, minutes, times,
# Nearest to he: she, they, it, there, we, who, bosco, eventually,
# Nearest to if: when, though, where, before, did, cannot, although, since,
# Nearest to a: another, veritas, the, kerk, emanation, every, exchangeable, devo,
# Nearest to united: uk, confederate, mim, athenian, member, romans, nearby, usc,
# Nearest to state: states, government, city, constitution, donau, municipal, sprint, congress,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to they: we, he, there, you, she, it, i, who,
# Nearest to often: sometimes, usually, frequently, commonly, typically, generally, also, now,
# Nearest to these: several, those, such, examples, all, many, some, ingolstadt,
# Nearest to some: many, several, certain, various, numerous, any, these, this,
# Nearest to his: her, their, its, your, my, our, whose, the,
# Nearest to american: canadian, australian, british, english, italian, german, russian, irish,
# Nearest to use: need, usage, support, sense, form, chiba, cause, signers,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
