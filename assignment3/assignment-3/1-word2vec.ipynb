# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.155716
# Nearest to states: sideways, cygnus, capitulated, airplanes, wally, abhidharma, heliogabalus, eratosthenes,
# Nearest to about: scuola, oneida, rubric, harbours, modes, charset, hughes, bene,
# Nearest to may: risings, sld, sherman, involved, eastward, analysts, scanning, chlorides,
# Nearest to after: edged, miami, equally, parnell, acl, laramie, moabites, knew,
# Nearest to was: stosunku, omphale, stitch, kowloon, equine, braque, taos, millionaires,
# Nearest to all: glacier, vespucci, eyelashes, ceuta, lui, vaginal, fetishes, tortuous,
# Nearest to while: acct, memo, locals, aware, tells, dicke, memoriam, railroad,
# Nearest to who: pomeranian, afro, depatie, korzybski, metro, trespass, currently, welding,
# Nearest to with: unaffected, baths, harmonious, integrins, resettle, maneuvers, blames, hotspots,
# Nearest to which: eagle, falsely, lewin, electromagnetic, erbium, conception, internally, xenophobic,
# Nearest to were: cabell, curried, stirling, amoebae, jogging, jagiello, myrrh, shameless,
# Nearest to three: straightening, jeffers, am, foul, vacations, thither, corresponded, reemergence,
# Nearest to their: alibi, revolts, durand, macedonia, bodywork, osu, peng, altenberg,
# Nearest to from: clutter, urinate, false, achieved, talladega, dismissal, coprophagia, kiki,
# Nearest to however: fastened, foreshadow, aries, babylonia, newsreel, regards, discouraging, monocotyledons,
# Nearest to it: conflict, constructivism, brabant, sonorants, accademia, quite, resentment, chickens,
# Average loss at step 2000: 4.367092
# Average loss at step 4000: 3.859394
# Average loss at step 6000: 3.792313
# Average loss at step 8000: 3.687691
# Average loss at step 10000: 3.615810
# Nearest to states: abhidharma, retinal, cleese, wally, romanticized, eratosthenes, apathy, northwestern,
# Nearest to about: rubric, absorbance, fielded, akbar, autistic, sous, affront, skilling,
# Nearest to may: can, murals, mismanagement, could, sherman, anoa, involved, standalone,
# Nearest to after: in, for, through, behind, by, sun, phodopus, witwatersrand,
# Nearest to was: is, were, had, has, by, be, been, are,
# Nearest to all: glacier, feature, swirling, vespucci, swaps, campaigned, flogging, some,
# Nearest to while: railroad, showed, whipple, memo, kapoor, hiking, memoriam, bahasa,
# Nearest to who: he, schr, still, currently, which, and, joab, not,
# Nearest to with: in, handlebars, for, prasad, between, integrins, dusseldorf, book,
# Nearest to which: that, this, it, also, palomino, who, simulate, he,
# Nearest to were: are, was, cabell, beatboxing, pinchcliffe, asser, volo, is,
# Nearest to three: five, eight, four, six, seven, two, nine, zero,
# Nearest to their: his, its, the, dutt, osu, convictions, macedonia, durand,
# Nearest to from: in, into, by, for, ecosystem, eyeglasses, visualisation, accessibility,
# Nearest to however: since, foreshadow, devils, amazonas, aries, fastened, lovejoy, discouraging,
# Nearest to it: he, there, this, she, they, not, which, stews,
# Average loss at step 12000: 3.604790
# Average loss at step 14000: 3.576437
# Average loss at step 16000: 3.408642
# Average loss at step 18000: 3.463076
# Average loss at step 20000: 3.541302
# Nearest to states: abhidharma, apathy, northwestern, foulke, motocross, downtown, memorial, wally,
# Nearest to about: rubric, akbar, skilling, absorbance, thrace, ting, burundian, sous,
# Nearest to may: can, could, would, might, should, will, must, murals,
# Nearest to after: before, through, when, in, by, sun, for, behind,
# Nearest to was: is, has, had, were, became, been, phalanx, when,
# Nearest to all: some, many, these, feature, glacier, customization, siege, hostels,
# Nearest to while: when, railroad, showed, although, memo, whipple, but, if,
# Nearest to who: he, which, they, then, she, still, also, currently,
# Nearest to with: between, in, by, handlebars, for, from, warmer, prasad,
# Nearest to which: that, this, who, also, it, there, but, never,
# Nearest to were: are, was, had, have, being, is, by, nster,
# Nearest to three: four, seven, six, five, two, eight, zero, nine,
# Nearest to their: its, his, the, her, some, decorate, any, your,
# Nearest to from: into, in, by, at, carefully, with, after, loi,
# Nearest to however: but, since, although, aries, actually, that, amazonas, phobos,
# Nearest to it: he, there, this, they, which, not, she, we,
# Average loss at step 22000: 3.500466
# Average loss at step 24000: 3.487311
# Average loss at step 26000: 3.484143
# Average loss at step 28000: 3.476173
# Average loss at step 30000: 3.507508
# Nearest to states: state, abhidharma, northwestern, motocross, memorial, harnesses, downtown, impressionists,
# Nearest to about: skilling, burundian, rubric, sous, affront, masovia, falsehood, akbar,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to after: before, when, through, during, killing, at, behind, until,
# Nearest to was: is, had, were, became, has, been, when, be,
# Nearest to all: some, these, many, customization, various, flogging, step, any,
# Nearest to while: although, when, but, railroad, showed, if, nat, backs,
# Nearest to who: he, they, she, which, there, currently, actually, also,
# Nearest to with: between, in, by, handlebars, when, against, prasad, for,
# Nearest to which: this, that, also, who, it, but, what, falk,
# Nearest to were: are, was, have, had, being, be, ashley, been,
# Nearest to three: four, seven, five, eight, six, two, nine, zero,
# Nearest to their: its, his, the, her, these, your, any, some,
# Nearest to from: into, in, between, of, under, by, during, and,
# Nearest to however: but, although, since, that, amazonas, though, actually, curie,
# Nearest to it: he, there, this, she, they, which, theseus, also,
# Average loss at step 32000: 3.502730
# Average loss at step 34000: 3.497028
# Average loss at step 36000: 3.458336
# Average loss at step 38000: 3.302531
# Average loss at step 40000: 3.428404
# Nearest to states: kingdom, northwestern, nations, abhidharma, harnesses, state, downtown, foulke,
# Nearest to about: epimorphism, falsehood, rubric, skilling, masovia, download, affront, burundian,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to after: before, during, when, through, had, redox, maratha, for,
# Nearest to was: is, became, has, had, were, been, be, when,
# Nearest to all: many, any, both, these, num, several, examples, customization,
# Nearest to while: although, when, but, railroad, were, are, though, where,
# Nearest to who: he, she, which, there, often, usually, they, no,
# Nearest to with: between, in, exterminating, from, on, handlebars, histone, when,
# Nearest to which: that, this, also, but, who, it, there, itself,
# Nearest to were: are, have, was, being, had, these, those, been,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to their: its, his, her, your, the, these, talking, some,
# Nearest to from: into, through, in, during, liner, under, with, between,
# Nearest to however: but, although, stealing, since, though, that, hess, actually,
# Nearest to it: he, there, she, they, this, which, but, what,
# Average loss at step 42000: 3.434534
# Average loss at step 44000: 3.453905
# Average loss at step 46000: 3.447889
# Average loss at step 48000: 3.353935
# Average loss at step 50000: 3.386586
# Nearest to states: kingdom, nations, downtown, party, northwestern, foulke, harnesses, warrior,
# Nearest to about: epimorphism, falsehood, skilling, rubric, download, masovia, prostaglandins, elba,
# Nearest to may: can, could, would, must, should, will, might, cannot,
# Nearest to after: before, when, during, through, for, while, under, by,
# Nearest to was: is, has, were, became, had, be, being, by,
# Nearest to all: both, every, various, many, some, examples, any, these,
# Nearest to while: when, although, however, but, where, though, and, until,
# Nearest to who: he, which, she, they, also, slapped, symbology, there,
# Nearest to with: between, handlebars, exterminating, against, in, by, chartered, when,
# Nearest to which: that, this, also, who, but, there, often, usually,
# Nearest to were: are, have, was, be, being, been, had, those,
# Nearest to three: four, six, seven, eight, two, five, nine, zero,
# Nearest to their: its, his, her, your, the, both, talking, whose,
# Nearest to from: into, through, in, under, during, across, and, within,
# Nearest to however: but, although, that, while, though, since, which, stealing,
# Nearest to it: he, she, there, they, this, theseus, transmit, now,
# Average loss at step 52000: 3.437285
# Average loss at step 54000: 3.430387
# Average loss at step 56000: 3.442349
# Average loss at step 58000: 3.397171
# Average loss at step 60000: 3.391409
# Nearest to states: nations, kingdom, party, balderus, countries, harnesses, northwestern, apathy,
# Nearest to about: epimorphism, over, download, rubric, skilling, falsehood, elba, masovia,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to after: before, during, when, despite, through, while, for, until,
# Nearest to was: is, had, became, were, has, forster, been, becomes,
# Nearest to all: those, some, various, any, many, every, these, both,
# Nearest to while: although, when, though, before, after, where, and, were,
# Nearest to who: which, he, now, she, usually, they, that, still,
# Nearest to with: between, handlebars, when, nguni, including, hydronium, against, nonsensical,
# Nearest to which: that, this, who, these, also, however, what, it,
# Nearest to were: are, was, have, those, had, been, including, although,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to their: its, his, her, the, your, whose, crystallizes, these,
# Nearest to from: through, into, in, renormalization, toward, manipulative, across, klaas,
# Nearest to however: but, although, though, that, which, since, stealing, curie,
# Nearest to it: he, there, she, this, booed, which, what, they,
# Average loss at step 62000: 3.247224
# Average loss at step 64000: 3.252560
# Average loss at step 66000: 3.404012
# Average loss at step 68000: 3.395557
# Average loss at step 70000: 3.358864
# Nearest to states: nations, kingdom, countries, state, harnesses, us, torrent, handhelds,
# Nearest to about: epimorphism, over, download, masovia, skilling, quotas, falsehood, on,
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to after: before, during, when, while, despite, through, redox, if,
# Nearest to was: is, has, had, became, were, lavin, been, logitech,
# Nearest to all: some, many, various, every, any, flogging, several, those,
# Nearest to while: although, when, though, before, after, however, if, where,
# Nearest to who: he, which, she, now, they, breve, rapes, jinnah,
# Nearest to with: between, handlebars, exterminating, nguni, when, in, analytical, weekend,
# Nearest to which: that, this, also, but, what, these, still, itself,
# Nearest to were: are, have, was, had, be, been, passers, cz,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to their: its, his, her, the, your, these, some, our,
# Nearest to from: into, through, across, in, under, between, toward, by,
# Nearest to however: but, although, though, that, where, while, when, since,
# Nearest to it: he, she, there, this, they, we, also, never,
# Average loss at step 72000: 3.381202
# Average loss at step 74000: 3.347520
# Average loss at step 76000: 3.320666
# Average loss at step 78000: 3.354983
# Average loss at step 80000: 3.374975
# Nearest to states: nations, kingdom, countries, state, us, harnesses, handhelds, party,
# Nearest to about: over, epimorphism, skilling, thrace, approximately, elba, falsehood, quotas,
# Nearest to may: can, could, would, might, will, must, should, cannot,
# Nearest to after: before, during, when, despite, while, until, without, from,
# Nearest to was: is, became, were, had, been, has, becomes, being,
# Nearest to all: many, various, every, both, some, any, multiple, these,
# Nearest to while: although, though, when, before, after, however, but, and,
# Nearest to who: he, which, they, she, usually, often, already, actually,
# Nearest to with: between, handlebars, akita, analytical, when, exterminating, histone, powder,
# Nearest to which: that, this, usually, who, also, based, these, it,
# Nearest to were: are, was, had, been, have, became, those, being,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to their: its, his, her, your, the, our, talking, both,
# Nearest to from: through, into, by, after, across, during, in, under,
# Nearest to however: although, but, though, that, while, since, where, when,
# Nearest to it: he, she, there, this, they, itself, we, not,
# Average loss at step 82000: 3.406002
# Average loss at step 84000: 3.412961
# Average loss at step 86000: 3.389729
# Average loss at step 88000: 3.350858
# Average loss at step 90000: 3.368006
# Nearest to states: kingdom, nations, us, countries, state, handhelds, nnp, waikato,
# Nearest to about: epimorphism, over, falsehood, elba, skilling, prostaglandins, download, durango,
# Nearest to may: can, could, would, might, will, must, should, cannot,
# Nearest to after: before, during, when, while, despite, without, until, leaving,
# Nearest to was: is, had, became, has, were, been, be, becomes,
# Nearest to all: some, many, various, several, any, every, both, these,
# Nearest to while: although, though, when, before, after, during, but, however,
# Nearest to who: he, often, which, already, she, now, still, breve,
# Nearest to with: between, by, in, when, using, serials, eurocard, from,
# Nearest to which: that, this, also, usually, but, what, both, itself,
# Nearest to were: are, had, was, have, these, while, those, being,
# Nearest to three: five, four, two, seven, eight, six, zero, nine,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to from: through, into, during, across, toward, in, including, within,
# Nearest to however: although, but, that, though, while, since, gacy, and,
# Nearest to it: he, she, there, this, they, itself, never, we,
# Average loss at step 92000: 3.400517
# Average loss at step 94000: 3.256012
# Average loss at step 96000: 3.364677
# Average loss at step 98000: 3.239762
# Average loss at step 100000: 3.360819
# Nearest to states: nations, kingdom, countries, state, us, northwestern, waikato, balderus,
# Nearest to about: epimorphism, skilling, falsehood, on, over, ufos, durango, tienne,
# Nearest to may: can, could, should, will, might, must, would, cannot,
# Nearest to after: before, during, when, despite, while, without, until, through,
# Nearest to was: is, became, had, has, were, been, becomes, although,
# Nearest to all: various, several, many, any, these, every, some, multiple,
# Nearest to while: although, when, though, before, after, however, unless, and,
# Nearest to who: he, often, still, which, already, now, actually, never,
# Nearest to with: between, including, janusz, when, depopulated, analytical, exterminating, by,
# Nearest to which: that, this, usually, what, however, these, who, actually,
# Nearest to were: are, was, have, these, include, had, those, while,
# Nearest to three: five, four, six, two, seven, eight, nine, zero,
# Nearest to their: its, his, her, your, our, the, whose, these,
# Nearest to from: through, into, toward, in, across, including, during, predicament,
# Nearest to however: although, but, that, though, while, which, especially, volution,
# Nearest to it: he, she, there, this, they, nothing, what, today,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ context_window target context_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[context_window]
        target = context_window
        k = 0
        for j in range(span):
            if j != context_window:
                batch[i][k] = buffer[j]
                k = k + 1
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for idx in range(8):
        print('    batch %d: %s' % (idx, [reverse_dictionary[bi] for bi in batch[idx]]))
        print('    label %d: %s' % (idx, reverse_dictionary[labels[idx, 0]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with context_window = 2:
#     batch 0: ['anarchism', 'originated', 'a', 'term']
#     label 0: as
#     batch 1: ['originated', 'as', 'term', 'of']
#     label 1: a
#     batch 2: ['as', 'a', 'of', 'abuse']
#     label 2: term
#     batch 3: ['a', 'term', 'abuse', 'first']
#     label 3: of
#     batch 4: ['term', 'of', 'first', 'used']
#     label 4: abuse
#     batch 5: ['of', 'abuse', 'used', 'against']
#     label 5: first
#     batch 6: ['abuse', 'first', 'against', 'early']
#     label 6: used
#     batch 7: ['first', 'used', 'early', 'working']
#     label 7: against
#
# with context_window = 4:
#     batch 0: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label 0: term
#     batch 1: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label 1: of
#     batch 2: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label 2: abuse
#     batch 3: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label 3: first
#     batch 4: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label 4: used
#     batch 5: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label 5: against
#     batch 6: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label 6: early
#     batch 7: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label 7: working

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # This is the alternative to skip_window, however we don't need the skip steps here,
                   # since all words are always included
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Get the sum of the embeddings for the each entry
    embedding_context = tf.reduce_sum(embed, 1)
     
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedding_context,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, context_window)
        print(batch_data)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.249686
# Nearest to th: professors, comedienne, stimulants, flatus, handles, blotter, emphasising, xxxiv,
# Nearest to been: generations, pendragon, skeleton, ramanujan, adnan, virgo, addressee, uther,
# Nearest to all: wedgwood, nissan, ergo, regress, sufficiency, deccan, tainted, answering,
# Nearest to seven: alcott, pause, dead, messina, wiseman, syndicalist, penalized, furnaces,
# Nearest to they: hologram, hindering, esb, chromosome, combatant, anesthetic, minimise, harm,
# Nearest to used: maximal, lexington, famer, ribera, cursus, automate, pipeline, zimbabwean,
# Nearest to five: taylor, punishment, exploit, ethnographic, masculinity, path, settle, capitalists,
# Nearest to about: elegans, companionship, gestapo, ghb, helsinki, deuterium, crescas, loophole,
# Nearest to years: reward, pungent, div, flamingo, noma, heredity, visicalc, commentarii,
# Nearest to no: exposed, arid, appliance, injustice, iona, atonal, uniformitarianism, astaire,
# Nearest to and: stamped, jarrett, tabula, astral, jennie, shi, generalizes, projector,
# Nearest to if: scopes, cue, layering, photography, granitic, carver, anchored, thaddeus,
# Nearest to which: placements, santiago, monomers, blockaded, overran, unverifiable, pounded, nakamura,
# Nearest to new: boarded, wakefield, noc, importantly, clemency, thirties, nlm, mooted,
# Nearest to he: bute, violins, synaptic, incorporation, gluon, printout, slits, whistle,
# Nearest to have: politicians, knuckles, sue, femininity, okinawan, midwest, warranted, farad,
# Average loss at step 2000: 4.096582
# Average loss at step 4000: 3.559418
# Average loss at step 6000: 3.381001
# Average loss at step 8000: 3.242504
# Average loss at step 10000: 3.177935
# Nearest to th: professors, pals, comedienne, preconditions, st, aldous, caps, nagel,
# Nearest to been: become, be, was, splintered, constructing, lepidoptera, pendragon, ostensibly,
# Nearest to all: both, many, those, bamboo, historiae, ergo, saloons, nontrivial,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to they: he, we, there, you, it, she, harriers, who,
# Nearest to used: found, known, optimized, crusading, circumcisions, infested, mari, bypass,
# Nearest to five: six, eight, seven, four, nine, three, zero, two,
# Nearest to about: arians, deuterium, oblivion, parkes, snowy, barra, mouvement, edmund,
# Nearest to years: reward, visicalc, spontaneously, cosmetics, others, rehearsing, integrating, nearly,
# Nearest to no: ellipsis, a, exposed, pogues, vespucci, joel, shall, pomeranian,
# Nearest to and: or, but, eagerly, benz, backstory, sip, totalled, ruined,
# Nearest to if: scopes, though, photography, cobra, anchored, puddle, generates, catarina,
# Nearest to which: that, this, it, who, these, also, helvetii, belfast,
# Nearest to new: melted, genitals, cve, corrected, ingrid, health, chased, savages,
# Nearest to he: it, she, they, who, there, harriers, mpa, atacama,
# Nearest to have: had, has, were, be, are, include, knuckles, appear,
# Average loss at step 12000: 3.200965
# Average loss at step 14000: 3.153895
# Average loss at step 16000: 3.177652
# Average loss at step 18000: 3.128639
# Average loss at step 20000: 2.990534
# Nearest to th: pals, aldous, preconditions, comedienne, professors, st, viii, swimming,
# Nearest to been: become, be, was, constructing, were, being, refutable, splintered,
# Nearest to all: both, those, bamboo, any, some, breeches, menu, many,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to they: we, there, he, you, it, harriers, she, gwen,
# Nearest to used: known, found, considered, applied, lesbianism, optimized, allowed, circumcisions,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to about: on, arians, fireball, spline, pelt, stoughton, quizzes, knuth,
# Nearest to years: cosmetics, others, ways, intrauterine, days, months, reward, visicalc,
# Nearest to no: any, cameroonian, a, inappropriate, ellipsis, another, vespucci, valois,
# Nearest to and: or, but, who, backstory, totalled, vorarlberg, hesitant, feud,
# Nearest to if: when, though, tiling, palacio, anesthetic, scopes, cobra, despite,
# Nearest to which: that, this, there, who, also, sousa, these, it,
# Nearest to new: creating, single, citrate, genomic, exclaimed, akkadian, curtains, savages,
# Nearest to he: she, it, they, who, harriers, eventually, i, there,
# Nearest to have: had, has, were, are, include, be, including, receive,
# Average loss at step 22000: 3.072595
# Average loss at step 24000: 3.039073
# Average loss at step 26000: 3.007437
# Average loss at step 28000: 3.023298
# Average loss at step 30000: 3.011038
# Nearest to th: pals, six, st, surinam, professors, comedienne, danmarks, four,
# Nearest to been: become, be, was, constructing, previously, tamias, translate, already,
# Nearest to all: both, those, any, every, some, bamboo, administratively, many,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to they: we, there, he, you, she, harriers, it, tipper,
# Nearest to used: known, found, applied, given, allowed, considered, defined, held,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Nearest to about: arians, on, fireball, pelt, spline, that, checksum, snowy,
# Nearest to years: days, months, year, decades, centuries, times, others, cosmetics,
# Nearest to no: any, little, rahilly, vespucci, weber, ellipsis, ahaz, brinkley,
# Nearest to and: or, but, including, however, although, karaoke, crystallography, backstory,
# Nearest to if: when, though, where, palacio, without, djinn, after, tiling,
# Nearest to which: that, this, who, however, usually, also, what, colloquium,
# Nearest to new: different, single, pinnacles, modern, whole, danish, replicas, curtains,
# Nearest to he: she, it, they, who, there, never, harriers, creeds,
# Nearest to have: had, has, were, are, include, refer, be, receive,
# Average loss at step 32000: 2.826098
# Average loss at step 34000: 2.954215
# Average loss at step 36000: 2.947618
# Average loss at step 38000: 2.942910
# Average loss at step 40000: 2.927252
# Nearest to th: surinam, pals, professors, comedienne, rd, st, rohypnol, viii,
# Nearest to been: become, be, was, tamias, constructing, were, being, previously,
# Nearest to all: both, any, many, every, some, those, various, several,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to they: we, he, you, there, she, harriers, i, it,
# Nearest to used: known, allowed, applied, found, defined, referred, considered, responsible,
# Nearest to five: six, seven, four, eight, nine, three, zero, two,
# Nearest to about: arians, knuth, on, pelt, ask, limes, checksum, fireball,
# Nearest to years: days, months, decades, year, centuries, times, hours, ways,
# Nearest to no: any, little, ahaz, saxony, benitez, brinkley, identical, weber,
# Nearest to and: or, while, including, but, ayrshire, beatboxing, too, decreased,
# Nearest to if: when, though, where, then, without, because, afrikaners, palacio,
# Nearest to which: this, that, what, usually, also, who, these, colloquium,
# Nearest to new: single, curtains, different, chores, replicas, mares, lamarr, dawkins,
# Nearest to he: she, it, they, there, who, harriers, we, this,
# Nearest to have: had, has, were, are, include, having, receive, be,
# Average loss at step 42000: 2.947845
# Average loss at step 44000: 2.961588
# Average loss at step 46000: 2.908901
# Average loss at step 48000: 2.872811
# Average loss at step 50000: 2.842580
# Nearest to th: fifth, rd, pals, surinam, next, st, sandpaper, cushion,
# Nearest to been: become, be, tamias, previously, was, recently, constructing, already,
# Nearest to all: both, many, several, every, various, saloons, any, multiple,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to they: we, there, you, he, she, it, harriers, douard,
# Nearest to used: applied, known, referred, defined, allowed, found, presented, designed,
# Nearest to five: four, six, seven, eight, nine, three, zero, two,
# Nearest to about: checksum, bosom, fireball, finish, spline, on, garonne, zfc,
# Nearest to years: days, decades, months, year, times, hours, weeks, centuries,
# Nearest to no: any, little, ahaz, another, only, rahilly, identical, wye,
# Nearest to and: or, but, although, including, while, ennedi, ftl, ayrshire,
# Nearest to if: when, though, where, without, then, because, before, glaze,
# Nearest to which: that, this, what, usually, also, often, generally, it,
# Nearest to new: old, different, modern, chores, dawkins, whole, curtains, melted,
# Nearest to he: she, it, they, there, who, harriers, never, eventually,
# Nearest to have: has, had, include, are, contain, were, receive, tend,
# Average loss at step 52000: 2.890866
# Average loss at step 54000: 2.865272
# Average loss at step 56000: 2.862278
# Average loss at step 58000: 2.752650
# Average loss at step 60000: 2.830754
# Nearest to th: fifth, second, nineteenth, st, surinam, next, rd, pals,
# Nearest to been: become, be, was, tamias, constructing, were, previously, recently,
# Nearest to all: both, every, many, various, those, any, several, saloons,
# Nearest to seven: five, six, nine, eight, four, zero, three, two,
# Nearest to they: we, you, there, he, she, it, harriers, douard,
# Nearest to used: defined, applied, presented, referred, known, described, seen, considered,
# Nearest to five: seven, four, six, eight, zero, nine, three, two,
# Nearest to about: around, regarding, on, spline, checksum, over, bosom, oromo,
# Nearest to years: days, months, decades, times, centuries, hours, year, weeks,
# Nearest to no: another, any, little, wye, only, become, identical, rahilly,
# Nearest to and: or, but, although, karaoke, kinsella, backstory, including, while,
# Nearest to if: when, though, where, before, without, after, then, although,
# Nearest to which: that, this, what, also, who, actually, usually, these,
# Nearest to new: different, separate, apprentices, old, single, modern, chores, jacoby,
# Nearest to he: she, it, they, harriers, soon, there, who, eventually,
# Nearest to have: had, has, were, having, are, include, be, receive,
# Average loss at step 62000: 2.834019
# Average loss at step 64000: 2.777408
# Average loss at step 66000: 2.758911
# Average loss at step 68000: 2.710560
# Average loss at step 70000: 2.782721
# Nearest to th: fifth, nineteenth, st, pals, next, third, prisms, fourteenth,
# Nearest to been: become, be, previously, tamias, were, was, ever, already,
# Nearest to all: both, various, many, every, saloons, bamboo, infertility, consist,
# Nearest to seven: six, five, nine, eight, four, three, zero, two,
# Nearest to they: we, you, he, there, she, harriers, it, these,
# Nearest to used: allowed, responsible, presented, defined, referred, found, described, known,
# Nearest to five: six, seven, four, nine, three, eight, zero, two,
# Nearest to about: spline, regarding, ask, zfc, wer, arians, stoughton, around,
# Nearest to years: days, months, decades, year, weeks, times, centuries, hours,
# Nearest to no: another, any, linger, wye, creationist, babcock, equipped, forbidden,
# Nearest to and: or, but, although, karaoke, including, sip, however, harpsichords,
# Nearest to if: when, though, before, after, where, follows, mischief, tiling,
# Nearest to which: that, this, also, what, usually, who, actually, there,
# Nearest to new: different, separate, former, single, particular, heretic, fourth, previous,
# Nearest to he: she, it, they, who, there, eventually, soon, we,
# Nearest to have: had, has, include, having, receive, refer, be, contain,
# Average loss at step 72000: 2.794832
# Average loss at step 74000: 2.649097
# Average loss at step 76000: 2.804536
# Average loss at step 78000: 2.826994
# Average loss at step 80000: 2.781941
# Nearest to th: fifth, six, st, nineteenth, nd, pals, prisms, eight,
# Nearest to been: become, be, was, were, already, ever, recently, remained,
# Nearest to all: both, various, many, several, some, any, every, exclusively,
# Nearest to seven: six, nine, eight, five, four, three, zero, two,
# Nearest to they: we, you, he, there, she, i, harriers, it,
# Nearest to used: known, designed, responsible, found, allowed, defined, described, referred,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to about: arians, concerning, over, approximately, around, regarding, ask, zfc,
# Nearest to years: days, months, decades, hours, weeks, times, minutes, year,
# Nearest to no: any, wye, linger, another, brinkley, ahaz, metallica, karenga,
# Nearest to and: or, including, but, although, however, karaoke, etc, though,
# Nearest to if: when, though, before, where, subscripts, then, hoff, since,
# Nearest to which: that, this, what, but, these, usually, also, often,
# Nearest to new: different, previous, particular, single, special, fictional, multiple, specific,
# Nearest to he: she, it, they, who, there, harriers, soon, we,
# Nearest to have: had, has, include, were, having, are, contain, tend,
# Average loss at step 82000: 2.666075
# Average loss at step 84000: 2.772606
# Average loss at step 86000: 2.739738
# Average loss at step 88000: 2.751529
# Average loss at step 90000: 2.732005
# Nearest to th: fifth, six, eight, five, nineteenth, fourteenth, third, seven,
# Nearest to been: become, be, remained, tamias, occurred, already, previously, recently,
# Nearest to all: both, various, many, every, any, some, saloons, our,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to they: we, you, he, there, she, i, harriers, it,
# Nearest to used: designed, referred, known, described, found, allowed, called, responsible,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to about: around, spline, approximately, arians, regarding, concerning, sending, over,
# Nearest to years: days, months, decades, hours, weeks, minutes, year, centuries,
# Nearest to no: any, another, little, publicacion, linger, nothing, beadwork, become,
# Nearest to and: or, including, but, although, backstory, plated, analgesics, karaoke,
# Nearest to if: when, though, before, where, hoff, glaze, after, without,
# Nearest to which: that, this, what, also, typically, who, usually, often,
# Nearest to new: previous, old, single, different, corporate, separate, braking, former,
# Nearest to he: she, it, they, there, we, who, harriers, segregation,
# Nearest to have: had, has, having, were, are, include, be, receive,
# Average loss at step 92000: 2.679565
# Average loss at step 94000: 2.725607
# Average loss at step 96000: 2.700721
# Average loss at step 98000: 2.362898
# Average loss at step 100000: 2.400727
# Nearest to th: fifth, fourteenth, nineteenth, rd, sixth, next, ninth, nd,
# Nearest to been: become, be, already, were, recently, remained, previously, tamias,
# Nearest to all: both, various, many, some, several, those, our, these,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to they: we, he, there, you, she, i, harriers, it,
# Nearest to used: designed, referred, known, defined, allowed, required, applied, described,
# Nearest to five: seven, four, eight, six, nine, three, zero, two,
# Nearest to about: around, regarding, approximately, spline, skies, spherically, chaim, julien,
# Nearest to years: days, decades, months, year, weeks, hours, minutes, centuries,
# Nearest to no: any, little, another, nothing, linger, ramanujan, invariably, batasuna,
# Nearest to and: or, but, karaoke, including, however, though, calif, gina,
# Nearest to if: when, though, before, tiling, without, glaze, after, follows,
# Nearest to which: what, that, this, also, usually, actually, who, typically,
# Nearest to new: old, jacoby, different, dativus, previous, particular, fourth, heretic,
# Nearest to he: she, it, they, there, who, we, harriers, fgth,
# Nearest to have: had, has, include, having, contain, receive, are, refer,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
