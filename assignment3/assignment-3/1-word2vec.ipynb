# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index    
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/angel/Desktop/deep-learning/assignment3/assignment-3/.assign3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.653630
# Nearest to were: leaching, chop, juxtaposition, sell, quinlan, hew, stepson, breathing,
# Nearest to to: archaic, appalled, leopard, tip, ans, micah, stepmother, cocalus,
# Nearest to often: servo, endowment, doctors, mendeleev, leftmost, circulate, industrialised, halmos,
# Nearest to there: zodiacal, underscored, taxonomy, highbury, concentrations, which, puget, contradictory,
# Nearest to however: babi, cornerstones, mormon, identification, territory, frigg, protects, guidebook,
# Nearest to world: fon, stephane, amun, sparingly, scenic, imperialism, theodora, gam,
# Nearest to i: fearsome, ffg, clears, chapelle, batavian, surname, xf, owls,
# Nearest to such: coals, simultaneity, turkish, driver, dweller, robber, supranational, aichi,
# Nearest to b: picks, residuals, gilbertese, ringo, blackhawks, shocks, cartoonist, promised,
# Nearest to are: loanwords, expiring, subtraction, junius, nast, espoo, frescoes, waged,
# Nearest to that: predates, studios, columbus, treat, dehydration, koresh, litter, ovulation,
# Nearest to after: pastry, magnificence, cutter, sandwiched, hardliners, arriving, tm, zigzag,
# Nearest to which: perceive, goodfellas, naturalistic, meyers, cropping, tenth, luddites, there,
# Nearest to new: edvard, lord, managerial, dispersing, sep, tundra, unwelcome, lawn,
# Nearest to only: furthered, carnivore, hyllus, nadu, kalinga, plugin, tritium, stallions,
# Nearest to can: silly, balas, ar, rowdy, extraordinary, muses, developing, tba,
# Average loss at step 2000: 4.367466
# Average loss at step 4000: 3.867592
# Average loss at step 6000: 3.787713
# Average loss at step 8000: 3.685503
# Average loss at step 10000: 3.615641
# Nearest to were: are, was, had, hasan, have, modernists, mnr, henderson,
# Nearest to to: archaic, leopard, not, ans, into, pitting, through, sweating,
# Nearest to often: also, chromatography, doctors, it, lovin, that, kwahu, halmos,
# Nearest to there: it, they, which, mean, paullus, these, still, highbury,
# Nearest to however: babi, liars, zealots, ans, largest, coupe, traditionally, amerindian,
# Nearest to world: amun, stephane, averroes, sparingly, kach, mercantile, long, ashes,
# Nearest to i: you, fearsome, chapelle, surname, ffg, butler, nominees, reorganizing,
# Nearest to such: aichi, oz, value, well, figs, joannes, biggest, termites,
# Nearest to b: follower, transnistrian, blackhawks, flagella, ancien, shocks, shi, fax,
# Nearest to are: were, is, have, dissenting, chesterfield, nb, hinckley, modernists,
# Nearest to that: which, beavis, studios, what, this, it, crossover, treat,
# Nearest to after: on, pastry, magnificence, before, abbots, during, neutralized, detect,
# Nearest to which: that, it, there, this, perceive, now, also, calibrate,
# Nearest to new: sep, lord, edvard, unwelcome, tundra, magnificat, almaty, stad,
# Nearest to only: furthered, hyllus, widely, limits, wyatt, continuously, bsi, lucasfilm,
# Nearest to can: may, silly, could, would, must, quota, maskhadov, rowdy,
# Average loss at step 12000: 3.601606
# Average loss at step 14000: 3.570289
# Average loss at step 16000: 3.410387
# Average loss at step 18000: 3.459436
# Average loss at step 20000: 3.538341
# Nearest to were: are, was, had, have, been, be, by, is,
# Nearest to to: will, would, archaic, appalled, sweating, can, may, leopard,
# Nearest to often: also, sometimes, it, now, there, which, generally, usually,
# Nearest to there: it, they, he, which, still, we, often, these,
# Nearest to however: but, babi, skim, zealots, liars, ans, which, receive,
# Nearest to world: mercantile, amun, sparingly, averroes, battery, pia, mannerheim, shevat,
# Nearest to i: you, ffg, ii, we, diagonals, g, butler, cups,
# Nearest to such: these, well, figs, known, other, zhu, aichi, epics,
# Nearest to b: d, radiant, granting, fax, ancien, flanagan, pusc, tessellations,
# Nearest to are: were, is, have, but, was, dissenting, be, chesterfield,
# Nearest to that: which, what, beavis, but, this, it, there, athanasius,
# Nearest to after: before, when, during, from, upon, by, colloidal, in,
# Nearest to which: that, who, this, it, also, there, now, but,
# Nearest to new: lord, unwelcome, edvard, grinding, almaty, ias, tundra, sep,
# Nearest to only: furthered, widely, wyatt, alone, bsi, mimic, limits, collapsing,
# Nearest to can: may, could, would, must, will, should, cannot, silly,
# Average loss at step 22000: 3.504515
# Average loss at step 24000: 3.490253
# Average loss at step 26000: 3.486645
# Average loss at step 28000: 3.479027
# Average loss at step 30000: 3.502081
# Nearest to were: are, was, have, had, been, is, tetris, be,
# Nearest to to: would, will, can, must, not, sweating, archaic, sapiens,
# Nearest to often: sometimes, usually, still, generally, also, now, there, commonly,
# Nearest to there: they, it, he, we, still, often, usually, this,
# Nearest to however: but, that, skim, zealots, traditionally, although, babi, deut,
# Nearest to world: mercantile, mannerheim, maximal, stephane, shevat, deposits, ashes, identification,
# Nearest to i: we, you, ii, g, they, ukrainians, fearsome, ffg,
# Nearest to such: well, these, figs, many, other, known, some, aichi,
# Nearest to b: d, granting, kirsten, hendrik, ekaterina, pmod, radiant, xenophobic,
# Nearest to are: were, have, is, while, these, be, gabon, include,
# Nearest to that: which, what, however, this, where, crossover, spice, beavis,
# Nearest to after: before, during, from, when, under, by, latent, upon,
# Nearest to which: this, that, who, it, also, what, there, but,
# Nearest to new: lord, sep, unwelcome, ias, title, langevin, splendid, magnificat,
# Nearest to only: wyatt, widely, taken, furthered, bsi, mimic, simply, lucasfilm,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Average loss at step 32000: 3.500447
# Average loss at step 34000: 3.495438
# Average loss at step 36000: 3.455075
# Average loss at step 38000: 3.300393
# Average loss at step 40000: 3.425431
# Nearest to were: are, was, have, had, been, be, while, tetris,
# Nearest to to: will, archaic, sweating, bouvet, can, leopard, ganga, answering,
# Nearest to often: usually, sometimes, generally, also, commonly, still, typically, frequently,
# Nearest to there: they, it, he, which, usually, still, these, now,
# Nearest to however: but, that, skim, although, which, traditionally, while, pitting,
# Nearest to world: mercantile, mannerheim, impaled, kach, lurker, maximal, stephane, mehr,
# Nearest to i: we, you, ii, they, g, he, butler, t,
# Nearest to such: these, well, known, many, figs, allergy, int, including,
# Nearest to b: d, saffron, noirs, e, hendrik, eclecticism, f, rightness,
# Nearest to are: were, have, is, be, include, while, temporal, these,
# Nearest to that: which, what, this, where, however, it, then, but,
# Nearest to after: before, during, when, while, from, nanometers, under, latent,
# Nearest to which: that, this, who, there, it, what, now, often,
# Nearest to new: peat, sudan, koko, kazimierz, panzer, lord, praxis, lexus,
# Nearest to only: bsi, mimic, lucasfilm, wyatt, taken, it, lexus, freising,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Average loss at step 42000: 3.436206
# Average loss at step 44000: 3.452975
# Average loss at step 46000: 3.452096
# Average loss at step 48000: 3.355895
# Average loss at step 50000: 3.381520
# Nearest to were: are, was, have, be, had, tetris, those, is,
# Nearest to to: archaic, would, sapiens, may, must, across, will, can,
# Nearest to often: usually, generally, sometimes, commonly, now, frequently, typically, still,
# Nearest to there: they, it, he, she, we, still, these, often,
# Nearest to however: but, although, while, that, skim, when, though, where,
# Nearest to world: kach, impaled, mannerheim, lurker, saxophone, aroma, ashes, appellant,
# Nearest to i: we, you, ii, g, they, butler, burghs, cyborgs,
# Nearest to such: well, these, known, many, allergy, figs, like, certain,
# Nearest to b: d, saffron, noirs, f, ladin, kerenyi, hendrik, litas,
# Nearest to are: were, is, have, be, was, these, dissenting, include,
# Nearest to that: which, however, what, where, but, strontium, this, blanton,
# Nearest to after: before, when, during, while, under, from, latent, throughout,
# Nearest to which: this, that, who, also, often, what, usually, now,
# Nearest to new: everlasting, former, sudan, kazimierz, primary, single, medved, gimmick,
# Nearest to only: freising, already, widely, mimic, wyatt, geelong, lucasfilm, granted,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Average loss at step 52000: 3.435992
# Average loss at step 54000: 3.422651
# Average loss at step 56000: 3.436589
# Average loss at step 58000: 3.397996
# Average loss at step 60000: 3.393323
# Nearest to were: are, was, have, had, those, although, while, been,
# Nearest to to: would, will, archaic, may, must, could, not, cannot,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, now, also,
# Nearest to there: they, it, he, still, now, we, she, often,
# Nearest to however: but, although, that, which, skim, when, though, while,
# Nearest to world: impaled, lurker, mannerheim, disavowed, saxophone, poisson, sais, cgs,
# Nearest to i: we, you, ii, g, t, turquoise, hyphenated, ffg,
# Nearest to such: well, known, these, many, allergy, certain, regarded, eigenstates,
# Nearest to b: d, c, f, p, granting, saffron, meir, m,
# Nearest to are: were, is, have, include, these, be, afi, temporal,
# Nearest to that: which, however, what, this, where, it, but, often,
# Nearest to after: before, during, when, while, under, despite, following, throughout,
# Nearest to which: that, this, what, however, who, it, but, also,
# Nearest to new: everlasting, optimates, monophonic, rocky, fledging, different, langevin, sudan,
# Nearest to only: first, already, dated, freising, just, taken, impress, mimic,
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Average loss at step 62000: 3.239406
# Average loss at step 64000: 3.258305
# Average loss at step 66000: 3.406739
# Average loss at step 68000: 3.394313
# Average loss at step 70000: 3.362237
# Nearest to were: are, have, was, had, be, although, while, been,
# Nearest to to: will, would, must, can, could, cannot, bouvet, archaic,
# Nearest to often: usually, sometimes, commonly, generally, now, typically, frequently, widely,
# Nearest to there: they, it, still, we, he, she, generally, now,
# Nearest to however: but, although, that, while, though, when, which, skim,
# Nearest to world: saxophone, lurker, maximal, stephane, impaled, aroma, boer, cerf,
# Nearest to i: you, we, ii, g, turquoise, hyphenated, iii, butler,
# Nearest to such: these, known, well, many, certain, allergy, other, various,
# Nearest to b: d, f, r, p, granting, g, saffron, e,
# Nearest to are: were, have, is, include, although, be, while, these,
# Nearest to that: which, however, what, this, but, often, where, generally,
# Nearest to after: before, during, when, while, tuatha, despite, following, indefatigable,
# Nearest to which: that, this, what, also, who, however, but, wpa,
# Nearest to new: everlasting, itanium, fledging, manila, former, different, predecessors, jaynes,
# Nearest to only: freising, granted, either, still, condom, not, wyatt, duryodhana,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Average loss at step 72000: 3.374378
# Average loss at step 74000: 3.349689
# Average loss at step 76000: 3.317968
# Average loss at step 78000: 3.354121
# Average loss at step 80000: 3.374486
# Nearest to were: are, was, had, have, be, although, while, those,
# Nearest to to: archaic, will, must, deepwater, would, sapiens, should, may,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, now, still,
# Nearest to there: they, it, he, she, still, usually, we, these,
# Nearest to however: although, but, while, that, though, when, where, conspiratorial,
# Nearest to world: saxophone, impaled, swap, lurker, mannerheim, maximal, aroma, stephane,
# Nearest to i: you, g, ii, we, iii, turquoise, mail, t,
# Nearest to such: well, these, known, certain, allergy, eigenstates, follows, opposed,
# Nearest to b: d, granting, f, q, r, eclecticism, saffron, elaborately,
# Nearest to are: were, is, include, have, although, those, be, require,
# Nearest to that: which, however, what, where, heightened, although, uthman, nymphs,
# Nearest to after: before, during, when, despite, while, without, upon, tuatha,
# Nearest to which: that, this, also, usually, often, typically, who, what,
# Nearest to new: optimates, sudan, rocky, old, everlasting, different, additive, nevada,
# Nearest to only: wyatt, hoplites, duryodhana, first, furthered, bonaventure, last, chaco,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Average loss at step 82000: 3.408150
# Average loss at step 84000: 3.411534
# Average loss at step 86000: 3.393041
# Average loss at step 88000: 3.355380
# Average loss at step 90000: 3.365570
# Nearest to were: are, had, was, while, have, although, those, absurdist,
# Nearest to to: will, archaic, deepwater, would, must, should, polaris, sapiens,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, widely,
# Nearest to there: they, it, he, she, still, we, generally, sometimes,
# Nearest to however: but, although, that, while, though, especially, since, enduring,
# Nearest to world: appreciative, poisson, saxophone, coincides, cerf, deposits, prostaglandins, comparative,
# Nearest to i: you, g, we, ii, iii, turquoise, mail, t,
# Nearest to such: well, known, certain, these, follows, outspoken, eigenstates, many,
# Nearest to b: d, f, q, r, granting, semester, g, saffron,
# Nearest to are: were, include, is, although, have, these, while, those,
# Nearest to that: which, however, what, but, peninsulas, spice, lynched, excused,
# Nearest to after: before, during, when, while, despite, upon, until, without,
# Nearest to which: that, this, what, also, usually, but, these, often,
# Nearest to new: rocky, different, old, optimates, langevin, additive, forte, sudan,
# Nearest to only: wyatt, bonaventure, diophantine, taken, freising, even, walking, every,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Average loss at step 92000: 3.400678
# Average loss at step 94000: 3.257781
# Average loss at step 96000: 3.359274
# Average loss at step 98000: 3.243568
# Average loss at step 100000: 3.361225
# Nearest to were: are, was, have, had, although, these, absurdist, those,
# Nearest to to: will, would, must, could, can, towards, should, cannot,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, still,
# Nearest to there: they, he, it, still, she, we, generally, often,
# Nearest to however: but, although, that, while, and, though, especially, there,
# Nearest to world: swap, saxophone, lurker, poisson, tradeoff, gangs, prostaglandins, lapd,
# Nearest to i: you, ii, we, iii, g, turquoise, mail, they,
# Nearest to such: known, well, these, certain, many, follows, opposed, allergy,
# Nearest to b: d, granting, polemical, governorates, khan, replay, robert, q,
# Nearest to are: were, although, have, these, while, include, temporal, is,
# Nearest to that: which, however, what, heightened, lynched, who, spice, but,
# Nearest to after: before, during, when, despite, while, without, upon, although,
# Nearest to which: that, this, usually, actually, wpa, what, typically, these,
# Nearest to new: different, sudan, rocky, specific, old, langevin, additive, theological,
# Nearest to only: freising, wyatt, usually, latter, diophantine, rarely, not, already,
# Nearest to can: may, could, must, will, would, should, cannot, might,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[context_window]
        target = context_window
        targets_to_avoid = [ context_window ]
        k = 0
        for j in range(span):
            if j != context_window:
                batch[i][k] = buffer[j]
                k = k + 1
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for idx in range(8):
        print('    batch %d: %s' % (idx, [reverse_dictionary[bi] for bi in batch[idx]]))
        print('    label %d: %s' % (idx, reverse_dictionary[labels[idx, 0]]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with context_window = 2:
#     batch 0: ['anarchism', 'originated', 'a', 'term']
#     label 0: as
#     batch 1: ['originated', 'as', 'term', 'of']
#     label 1: a
#     batch 2: ['as', 'a', 'of', 'abuse']
#     label 2: term
#     batch 3: ['a', 'term', 'abuse', 'first']
#     label 3: of
#     batch 4: ['term', 'of', 'first', 'used']
#     label 4: abuse
#     batch 5: ['of', 'abuse', 'used', 'against']
#     label 5: first
#     batch 6: ['abuse', 'first', 'against', 'early']
#     label 6: used
#     batch 7: ['first', 'used', 'early', 'working']
#     label 7: against
#
# with context_window = 4:
#     batch 0: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label 0: term
#     batch 1: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label 1: of
#     batch 2: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label 2: abuse
#     batch 3: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label 3: first
#     batch 4: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label 4: used
#     batch 5: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label 5: against
#     batch 6: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label 6: early
#     batch 7: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label 7: working

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # This is the alternative to skip_window, however we don't need the skip steps here,
                   # since all words are always included
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Get the mean of the embeddings for the current label
    embedding_context = tf.reduce_mean(embed, 1)
    #print(embed.shape)
     
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedding_context,
                                 labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.708253
# Nearest to zero: rubber, eapc, amnon, erotica, cogency, janusz, edi, dashiell,
# Nearest to d: colleen, lobbied, enlarged, alexandrovna, inhibiting, conservatoire, attainder, sayfawa,
# Nearest to an: shearer, yeah, residuals, ramos, hydras, mo, naive, chichester,
# Nearest to i: fission, nets, heroically, separates, hawker, october, filmfare, unfolding,
# Nearest to or: deprogramming, napier, hearing, atreus, strips, projectiles, elders, querying,
# Nearest to are: steeper, lied, appreciating, sup, mandible, rial, burks, gol,
# Nearest to have: hatti, museo, epic, electrocution, curriculum, resented, breads, fa,
# Nearest to after: horror, notional, sledge, feature, inform, remembrance, bluebird, immortal,
# Nearest to six: russo, kifl, barrage, motherhood, disasters, triadic, lola, ftp,
# Nearest to seven: inhale, complaint, sauropods, ciphertexts, overdoses, weinberger, jungle, idi,
# Nearest to over: submission, stuka, pleistocene, abkhazia, accented, credentials, cryptic, steinberg,
# Nearest to at: chd, manama, signify, beverly, ham, literatures, dis, perpetuity,
# Nearest to may: articles, thermoregulation, sauron, polytechnical, chalcedon, staggering, jehoash, companies,
# Nearest to called: nabataean, defender, wm, cleared, poulsen, sporty, possible, diocese,
# Nearest to no: echelon, sima, sojourn, fo, unprotected, homesick, loyalists, farley,
# Nearest to not: arukh, emanated, bounty, happenings, bottled, forza, wily, uwe,
# Average loss at step 2000: 4.033664
# Average loss at step 4000: 3.505261
# Average loss at step 6000: 3.344515
# Average loss at step 8000: 3.197569
# Average loss at step 10000: 3.149432
# Nearest to zero: five, eight, seven, nine, six, four, three, formulate,
# Nearest to d: b, o, inhibiting, c, darling, apennines, hamar, berne,
# Nearest to an: shearer, ramos, chile, hitchens, hummers, ponies, yeah, argonne,
# Nearest to i: ii, graphs, brant, capabilities, cinco, separates, filmfare, panamanian,
# Nearest to or: and, de, csf, aikman, unproven, neutron, einsatzgruppen, jarman,
# Nearest to are: were, is, visibility, gol, litigated, have, pastiches, octopus,
# Nearest to have: had, be, has, were, jammu, are, fa, detectives,
# Nearest to after: before, cumin, during, sledge, benno, immortal, horror, philippians,
# Nearest to six: eight, nine, five, four, three, seven, two, zero,
# Nearest to seven: nine, eight, six, zero, four, three, five, two,
# Nearest to over: reigned, submission, ethidium, jekyll, indexing, pleistocene, if, ruud,
# Nearest to at: in, contaminants, during, precincts, septimius, injera, includes, adrienne,
# Nearest to may: can, would, must, could, might, should, will, chalcedon,
# Nearest to called: possible, deviate, archiepiscopal, nabataean, hanyu, stewards, scioto, morphemes,
# Nearest to no: this, tart, dei, another, shingles, morehouse, aulus, lawmakers,
# Nearest to not: guildhall, clipped, often, bounty, installed, also, only, arukh,
# Average loss at step 12000: 3.169910
# Average loss at step 14000: 3.129915
# Average loss at step 16000: 3.151860
# Average loss at step 18000: 3.104974
# Average loss at step 20000: 2.991971
# Nearest to zero: eight, seven, six, five, nine, four, three, planners,
# Nearest to d: b, o, enlarged, hamar, inhibiting, apennines, darling, c,
# Nearest to an: shearer, chile, ramos, hummers, dp, yeah, ponies, shaded,
# Nearest to i: ii, you, graphs, we, he, bowhunting, brant, cinco,
# Nearest to or: and, csf, einsatzgruppen, aikman, presbyters, de, pup, unproven,
# Nearest to are: were, have, is, litigated, including, be, visibility, chateau,
# Nearest to have: had, has, were, are, be, include, detectives, jammu,
# Nearest to after: before, during, immortal, cumin, sledge, later, benno, tool,
# Nearest to six: eight, four, seven, five, three, nine, zero, two,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to over: reigned, submission, ethidium, indexing, jekyll, pleistocene, ruud, nuclear,
# Nearest to at: in, repay, injera, heraclius, against, contaminants, inquiry, greifswald,
# Nearest to may: can, would, must, could, might, will, should, cannot,
# Nearest to called: badges, archiepiscopal, lev, near, deviate, scioto, opera, jacobin,
# Nearest to no: another, any, dei, indecent, pickles, tart, this, a,
# Nearest to not: usually, you, never, often, guildhall, installed, still, only,
# Average loss at step 22000: 3.057278
# Average loss at step 24000: 3.023050
# Average loss at step 26000: 2.988596
# Average loss at step 28000: 3.011560
# Average loss at step 30000: 2.991449
# Nearest to zero: seven, five, eight, six, four, nine, three, u,
# Nearest to d: b, o, inhibiting, apennines, enlarged, hamar, darling, milwaukee,
# Nearest to an: chile, shearer, ramos, yeah, hummers, dp, hitchens, bronchitis,
# Nearest to i: ii, you, graphs, bowhunting, we, brant, capabilities, voiceover,
# Nearest to or: and, than, aikman, pathologist, einsatzgruppen, csf, paraffin, magdeburg,
# Nearest to are: were, have, is, including, be, litigated, elly, gol,
# Nearest to have: had, has, are, were, be, include, offer, breads,
# Nearest to after: before, during, when, later, immortal, hostname, allegedly, sledge,
# Nearest to six: four, five, eight, seven, three, nine, two, zero,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to over: ethidium, reigned, submission, jekyll, around, nuclear, railhead, indexing,
# Nearest to at: in, injera, repay, under, during, against, contaminants, underestimate,
# Nearest to may: can, would, must, could, should, might, will, cannot,
# Nearest to called: badges, scioto, upscale, near, jacobin, archiepiscopal, hates, opera,
# Nearest to no: any, another, little, indecent, pastoral, pickles, sojourn, lawmakers,
# Nearest to not: usually, never, still, you, extremely, confessional, installed, guildhall,
# Average loss at step 32000: 2.842568
# Average loss at step 34000: 2.947415
# Average loss at step 36000: 2.939959
# Average loss at step 38000: 2.936665
# Average loss at step 40000: 2.923114
# Nearest to zero: seven, eight, five, six, nine, four, three, dimensional,
# Nearest to d: b, o, enlarged, inhibiting, apennines, darling, hamar, yaoi,
# Nearest to an: shearer, chile, argonne, gratis, hummers, ramos, yeah, ponies,
# Nearest to i: ii, you, we, voiceover, graphs, superimposed, galt, bowhunting,
# Nearest to or: and, than, magdeburg, peugeot, presbyters, pathologist, csf, thundering,
# Nearest to are: were, have, is, including, be, litigated, timed, darwinian,
# Nearest to have: had, has, are, were, offer, include, be, detectives,
# Nearest to after: before, during, when, benno, hostname, immortal, later, sledge,
# Nearest to six: five, eight, four, seven, three, nine, two, zero,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to over: penetrative, ethidium, around, reigned, profession, negus, indexing, ruud,
# Nearest to at: in, during, against, repay, injera, indicating, under, contaminants,
# Nearest to may: can, would, must, could, should, will, might, cannot,
# Nearest to called: badges, considered, referred, hates, loch, academies, opera, upscale,
# Nearest to no: any, indecent, little, another, lawmakers, sojourn, pastoral, presque,
# Nearest to not: never, still, usually, almost, confessional, installed, you, probably,
# Average loss at step 42000: 2.938011
# Average loss at step 44000: 2.943945
# Average loss at step 46000: 2.902464
# Average loss at step 48000: 2.868947
# Average loss at step 50000: 2.848132
# Nearest to zero: five, eight, seven, six, nine, four, three, u,
# Nearest to d: b, o, bok, inhibiting, quarterbacks, enlarged, hamar, apennines,
# Nearest to an: shearer, chile, gratis, ramos, hummers, argonne, bribes, bronchitis,
# Nearest to i: ii, you, we, aliphatic, galt, graphs, brant, v,
# Nearest to or: and, than, pathologist, but, csf, aikman, thundering, callet,
# Nearest to are: were, have, is, be, including, been, include, although,
# Nearest to have: had, has, are, were, offer, include, require, provide,
# Nearest to after: before, during, when, hostname, while, immortal, until, wallenberg,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to over: around, ethidium, penetrative, submission, indexing, reigned, jekyll, clad,
# Nearest to at: in, during, repay, under, on, indicating, pace, ventura,
# Nearest to may: can, could, must, would, should, will, might, cannot,
# Nearest to called: referred, badges, named, used, academies, catenary, loch, hates,
# Nearest to no: any, another, little, indecent, pastoral, bal, sojourn, ncs,
# Nearest to not: never, still, almost, usually, bia, installed, only, shocking,
# Average loss at step 52000: 2.885445
# Average loss at step 54000: 2.864510
# Average loss at step 56000: 2.861875
# Average loss at step 58000: 2.766074
# Average loss at step 60000: 2.825304
# Nearest to zero: five, seven, six, eight, nine, four, three, drivetrain,
# Nearest to d: b, o, r, inhibiting, quarterbacks, bok, enlarged, hamar,
# Nearest to an: shearer, gratis, chile, bronchitis, argonne, yeah, hummers, bribes,
# Nearest to i: ii, you, we, g, brant, graphs, sapiens, sommerfeld,
# Nearest to or: and, aikman, than, magdeburg, csf, presbyters, thundering, adventurer,
# Nearest to are: were, have, is, be, including, been, include, those,
# Nearest to have: had, has, are, were, offer, be, provide, require,
# Nearest to after: before, during, when, while, hostname, wallenberg, if, until,
# Nearest to six: five, seven, eight, four, nine, three, two, zero,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Nearest to over: around, penetrative, indexing, ethidium, accented, into, croats, toss,
# Nearest to at: in, during, indicating, on, under, repay, near, injera,
# Nearest to may: can, could, must, would, should, will, might, cannot,
# Nearest to called: referred, named, used, badges, academies, loch, catenary, considered,
# Nearest to no: another, any, little, indecent, sojourn, finegold, ncs, tart,
# Nearest to not: never, always, still, usually, almost, now, probably, actually,
# Average loss at step 62000: 2.834636
# Average loss at step 64000: 2.778943
# Average loss at step 66000: 2.772321
# Average loss at step 68000: 2.721974
# Average loss at step 70000: 2.777781
# Nearest to zero: eight, seven, five, six, four, nine, three, two,
# Nearest to d: b, bok, r, quarterbacks, enlarged, inhibiting, o, hamar,
# Nearest to an: shearer, chile, gratis, hummers, argonne, ramos, bronchitis, hitchens,
# Nearest to i: you, we, ii, graphs, aliphatic, g, htp, galt,
# Nearest to or: and, than, aikman, presbyters, csf, voiceless, creams, perlman,
# Nearest to are: were, have, is, include, be, including, those, restrained,
# Nearest to have: had, has, offer, are, were, require, include, contain,
# Nearest to after: before, during, when, while, hostname, wallenberg, thereafter, activism,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Nearest to over: around, through, into, dnow, accented, submission, tempe, ethidium,
# Nearest to at: in, during, indicating, on, under, near, repay, underestimate,
# Nearest to may: can, could, must, would, should, will, might, cannot,
# Nearest to called: named, referred, badges, used, academies, loch, catenary, fumimaro,
# Nearest to no: another, any, little, indecent, pastoral, tart, ncs, tvs,
# Nearest to not: never, always, now, actually, almost, still, bia, usually,
# Average loss at step 72000: 2.798940
# Average loss at step 74000: 2.661857
# Average loss at step 76000: 2.802660
# Average loss at step 78000: 2.827590
# Average loss at step 80000: 2.780273
# Nearest to zero: seven, eight, five, six, four, nine, three, sq,
# Nearest to d: b, r, quarterbacks, bok, kildare, hamar, sunga, soi,
# Nearest to an: argonne, shearer, chile, bronchitis, gratis, hummers, yeah, ponies,
# Nearest to i: you, we, ii, they, never, htp, aliphatic, gargoyles,
# Nearest to or: and, than, aikman, csf, magdeburg, callet, creams, presbyters,
# Nearest to are: were, have, is, include, including, be, remain, litigated,
# Nearest to have: had, has, were, are, offer, include, having, provide,
# Nearest to after: before, during, when, while, although, for, despite, without,
# Nearest to six: five, eight, seven, four, nine, three, zero, two,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to over: around, through, accented, submission, suo, penetrative, dnow, indexing,
# Nearest to at: during, in, near, indicating, under, throughout, legged, tatra,
# Nearest to may: can, could, might, would, will, must, should, cannot,
# Nearest to called: named, referred, badges, loch, catenary, academies, used, known,
# Nearest to no: another, any, little, indecent, pastoral, specification, patrilineal, tvs,
# Nearest to not: almost, never, always, still, really, actually, bia, shocking,
# Average loss at step 82000: 2.674809
# Average loss at step 84000: 2.772150
# Average loss at step 86000: 2.743411
# Average loss at step 88000: 2.757111
# Average loss at step 90000: 2.745128
# Nearest to zero: seven, eight, five, six, four, nine, three, million,
# Nearest to d: b, kildare, r, enlarged, quarterbacks, kumquats, sunga, hamar,
# Nearest to an: shearer, bronchitis, chile, hummers, argonne, ponies, ramos, hitchens,
# Nearest to i: you, we, ii, they, aliphatic, gargoyles, htp, sommerfeld,
# Nearest to or: and, than, csf, khayyam, magdeburg, aikman, ly, though,
# Nearest to are: were, have, include, is, including, litigated, embodies, elly,
# Nearest to have: had, has, offer, are, were, include, having, contain,
# Nearest to after: before, during, when, while, despite, without, thereafter, although,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to over: around, indexing, through, off, submission, emitting, accented, ruud,
# Nearest to at: during, in, near, indicating, on, under, repay, behind,
# Nearest to may: can, could, would, must, might, will, should, cannot,
# Nearest to called: named, referred, used, badges, known, loch, catenary, preferred,
# Nearest to no: any, another, little, indecent, tvs, epp, bal, nothing,
# Nearest to not: never, always, actually, almost, really, otherwise, actively, now,
# Average loss at step 92000: 2.693861
# Average loss at step 94000: 2.730093
# Average loss at step 96000: 2.713718
# Average loss at step 98000: 2.391314
# Average loss at step 100000: 2.422343
# Nearest to zero: six, five, eight, four, seven, nine, three, two,
# Nearest to d: b, bok, sunga, kildare, enlarged, footwear, harmony, colin,
# Nearest to an: chile, argonne, shearer, bronchitis, hummers, gratis, hitchens, lipi,
# Nearest to i: you, we, ii, they, iii, pretoria, aliphatic, never,
# Nearest to or: and, than, though, dolmen, khayyam, magdeburg, voiceless, exponents,
# Nearest to are: were, have, include, is, be, litigated, including, those,
# Nearest to have: had, has, are, were, offer, include, having, require,
# Nearest to after: before, during, when, despite, without, while, thereafter, for,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to over: around, penetrative, ruud, ethidium, off, shoots, submission, indexing,
# Nearest to at: during, in, near, indicating, after, on, around, under,
# Nearest to may: can, could, must, might, would, should, will, cannot,
# Nearest to called: named, referred, used, badges, academies, known, loch, sorted,
# Nearest to no: any, another, little, tvs, indecent, stosunku, intercourse, ncs,
# Nearest to not: never, actually, always, really, actively, shocking, otherwise, almost,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:] # Transformed to 2D
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
